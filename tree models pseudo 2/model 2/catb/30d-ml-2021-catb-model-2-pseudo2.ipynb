# %%
# Familiar imports
import numpy as np
import pandas as pd
import random
import os
import time
import pickle
from pathlib import Path

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

from scipy.optimize import minimize

#import lightgbm as lgb
#import xgboost as xgb
import catboost as ctb

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # Parameters

# %%
target = 'target'

DEBUG = False

if DEBUG:
    N_ESTIMATORS = 1
    N_SPLITS = 2
    SEED = 17
    CVSEED = 17
    EARLY_STOPPING_ROUNDS = 1
    VERBOSE = 100
    #N_ITERS = 2
else:
    N_SPLITS = 10
    N_ESTIMATORS = 20000
    EARLY_STOPPING_ROUNDS = 200
    VERBOSE = 1000
    SEED = 17
    CVSEED = 17
    #N_ITERS = 10

# %%
def set_seed(seed=17):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
set_seed(SEED)

# %% [markdown]
# # Load data

# %%
# Load the training data
train = pd.read_csv("../input/30-days-of-ml/train.csv")
test = pd.read_csv("../input/30-days-of-ml/test.csv")
submission = pd.read_csv("../input/30-days-of-ml/sample_submission.csv")

# Preview the data
train.head()
# Out:
#    id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont5     cont6  \
# 0   1    B    B    B    C    B    B    A    E    C  ...  0.400361  0.160266
# 1   2    B    B    A    A    B    D    A    F    A  ...  0.533087  0.558922
# 2   3    A    A    A    C    B    D    A    D    A  ...  0.650609  0.375348
# 3   4    B    B    A    C    B    D    A    E    C  ...  0.668980  0.239061
# 4   6    A    A    A    C    B    D    A    E    A  ...  0.686964  0.420667
#
#       cont7     cont8     cont9    cont10    cont11    cont12    cont13  \
# 0  0.310921  0.389470  0.267559  0.237281  0.377873  0.322401  0.869850
# 1  0.516294  0.594928  0.341439  0.906013  0.921701  0.261975  0.465083
# 2  0.902567  0.555205  0.843531  0.748809  0.620126  0.541474  0.763846
# 3  0.732948  0.679618  0.574844  0.346010  0.714610  0.540150  0.280682
# 4  0.648182  0.684501  0.956692  1.000773  0.776742  0.625849  0.250823
#
#      target
# 0  8.113634
# 1  8.481233
# 2  8.364351
# 3  8.049253
# 4  7.972260
#
# [5 rows x 26 columns]

# %%
# Low MI scores
for pp in ["cat2","cat3","cat4","cat6"]:
    train.pop(pp)
    test.pop(pp)
train.head()
# Out:
#    id cat0 cat1 cat5 cat7 cat8 cat9     cont0     cont1     cont2  ...  \
# 0   1    B    B    B    E    C    N  0.201470 -0.014822  0.669699  ...
# 1   2    B    B    D    F    A    O  0.743068  0.367411  1.021605  ...
# 2   3    A    A    D    D    A    F  0.742708  0.310383 -0.012673  ...
# 3   4    B    B    D    E    C    K  0.429551  0.620998  0.577942  ...
# 4   6    A    A    D    E    A    N  1.058291  0.367492 -0.052389  ...
#
#       cont5     cont6     cont7     cont8     cont9    cont10    cont11  \
# 0  0.400361  0.160266  0.310921  0.389470  0.267559  0.237281  0.377873
# 1  0.533087  0.558922  0.516294  0.594928  0.341439  0.906013  0.921701
# 2  0.650609  0.375348  0.902567  0.555205  0.843531  0.748809  0.620126
# 3  0.668980  0.239061  0.732948  0.679618  0.574844  0.346010  0.714610
# 4  0.686964  0.420667  0.648182  0.684501  0.956692  1.000773  0.776742
#
#      cont12    cont13    target
# 0  0.322401  0.869850  8.113634
# 1  0.261975  0.465083  8.481233
# 2  0.541474  0.763846  8.364351
# 3  0.540150  0.280682  8.049253
# 4  0.625849  0.250823  7.972260
#
# [5 rows x 22 columns]

# %%
# Separate target from features
y = train['target']
features = train.drop(['id','target'], axis=1)

# Preview features
features.head()
# Out:
#   cat0 cat1 cat5 cat7 cat8 cat9     cont0     cont1     cont2     cont3  \
# 0    B    B    B    E    C    N  0.201470 -0.014822  0.669699  0.136278
# 1    B    B    D    F    A    O  0.743068  0.367411  1.021605  0.365798
# 2    A    A    D    D    A    F  0.742708  0.310383 -0.012673  0.576957
# 3    B    B    D    E    C    K  0.429551  0.620998  0.577942  0.280610
# 4    A    A    D    E    A    N  1.058291  0.367492 -0.052389  0.232407
#
#       cont4     cont5     cont6     cont7     cont8     cont9    cont10  \
# 0  0.610706  0.400361  0.160266  0.310921  0.389470  0.267559  0.237281
# 1  0.276853  0.533087  0.558922  0.516294  0.594928  0.341439  0.906013
# 2  0.285074  0.650609  0.375348  0.902567  0.555205  0.843531  0.748809
# 3  0.284667  0.668980  0.239061  0.732948  0.679618  0.574844  0.346010
# 4  0.287595  0.686964  0.420667  0.648182  0.684501  0.956692  1.000773
#
#      cont11    cont12    cont13
# 0  0.377873  0.322401  0.869850
# 1  0.921701  0.261975  0.465083
# 2  0.620126  0.541474  0.763846
# 3  0.714610  0.540150  0.280682
# 4  0.776742  0.625849  0.250823

# %% [markdown]
# # Preprocessing

# %%
# List of categorical columns
object_cols = [col for col in features.columns if 'cat' in col]

# ordinal-encode categorical columns
X = features.copy()
X_test = test.drop(['id'], axis=1).copy()
ordinal_encoder = OrdinalEncoder()
X[object_cols] = ordinal_encoder.fit_transform(features[object_cols])
X_test[object_cols] = ordinal_encoder.transform(test[object_cols])

# Preview the ordinal-encoded features
X.head()
# Out:
#    cat0  cat1  cat5  cat7  cat8  cat9     cont0     cont1     cont2     cont3  \
# 0   1.0   1.0   1.0   4.0   2.0  13.0  0.201470 -0.014822  0.669699  0.136278
# 1   1.0   1.0   3.0   5.0   0.0  14.0  0.743068  0.367411  1.021605  0.365798
# 2   0.0   0.0   3.0   3.0   0.0   5.0  0.742708  0.310383 -0.012673  0.576957
# 3   1.0   1.0   3.0   4.0   2.0  10.0  0.429551  0.620998  0.577942  0.280610
# 4   0.0   0.0   3.0   4.0   0.0  13.0  1.058291  0.367492 -0.052389  0.232407
#
#       cont4     cont5     cont6     cont7     cont8     cont9    cont10  \
# 0  0.610706  0.400361  0.160266  0.310921  0.389470  0.267559  0.237281
# 1  0.276853  0.533087  0.558922  0.516294  0.594928  0.341439  0.906013
# 2  0.285074  0.650609  0.375348  0.902567  0.555205  0.843531  0.748809
# 3  0.284667  0.668980  0.239061  0.732948  0.679618  0.574844  0.346010
# 4  0.287595  0.686964  0.420667  0.648182  0.684501  0.956692  1.000773
#
#      cont11    cont12    cont13
# 0  0.377873  0.322401  0.869850
# 1  0.921701  0.261975  0.465083
# 2  0.620126  0.541474  0.763846
# 3  0.714610  0.540150  0.280682
# 4  0.776742  0.625849  0.250823

# %%
'''
# List of categorical columns
object_cols = [col for col in features.columns if 'cat' in col]

# one-hot-encode categorical columns
X = features.copy()
X_test = test.drop(['id'], axis=1).copy()

oh_encoder = OneHotEncoder(sparse=False, handle_unknown="ignore")
X_ohe = oh_encoder.fit_transform(features[object_cols])
X_test_ohe = oh_encoder.transform(test[object_cols])

X_ohe = pd.DataFrame(X_ohe, columns=[f"ohe_{i}" for i in range(X_ohe.shape[1])])
X_test_ohe = pd.DataFrame(X_test_ohe, columns=[f"ohe_{i}" for i in range(X_test_ohe.shape[1])])

X = pd.concat([X, X_ohe], axis=1)
X_test = pd.concat([X_test, X_test_ohe], axis=1)
X = X.drop(object_cols, axis=1)
X_test = X_test.drop(object_cols, axis=1)
    
# Preview the one-hot-encoded features
X.head()
'''
# Out:
# '\n# List of categorical columns\nobject_cols = [col for col in features.columns if \'cat\' in col]\n\n# one-hot-encode categorical columns\nX = features.copy()\nX_test = test.drop([\'id\'], axis=1).copy()\n\noh_encoder = OneHotEncoder(sparse=False, handle_unknown="ignore")\nX_ohe = oh_encoder.fit_transform(features[object_cols])\nX_test_ohe = oh_encoder.transform(test[object_cols])\n\nX_ohe = pd.DataFrame(X_ohe, columns=[f"ohe_{i}" for i in range(X_ohe.shape[1])])\nX_test_ohe = pd.DataFrame(X_test_ohe, columns=[f"ohe_{i}" for i in range(X_test_ohe.shape[1])])\n\nX = pd.concat([X, X_ohe], axis=1)\nX_test = pd.concat([X_test, X_test_ohe], axis=1)\nX = X.drop(object_cols, axis=1)\nX_test = X_test.drop(object_cols, axis=1)\n    \n# Preview the one-hot-encoded features\nX.head()\n'

# %%
scale_features = [col for col in features.columns if 'cont' in col]

ss = StandardScaler()
X[scale_features] = ss.fit_transform(features[scale_features])
X_test[scale_features] = ss.transform(test[scale_features])

# %%
# Swap noise

# Random
def apply_noise_rn(df, p=.75):
    should_not_swap = np.random.binomial(1, p, df.shape)
    corrupted_df = df.where(should_not_swap == 1, np.random.permutation(df))
    return corrupted_df

# Row-wise
def apply_noise_row(df, p=.75):
    should_not_swap = np.zeros(df.shape)
    for i in range(df.shape[0]):
        for j in np.random.choice(df.shape[1],int(p*df.shape[1]),replace=False):
            should_not_swap[i,j]=1 
    corrupted_df = df.where(should_not_swap == 1, np.random.permutation(df))
    return corrupted_df

# %% [markdown]
# # Pseudo Label

# %%
pseudo = pd.read_csv("../input/30dml-pseudo2/xgb_submission_k.txt")[target]
train_pseudo = pd.concat([X, y], axis=1)
test_pseudo = pd.concat([X_test, pseudo], axis=1)
all_pseudo = pd.concat([train_pseudo, test_pseudo]).reset_index(drop=True)

# %% [markdown]
# # CatB

# %%
ctb_params = {
            'loss_function': 'RMSE',
            'eval_metric': 'RMSE',
         'n_estimators':N_ESTIMATORS,
    
        'bootstrap_type': 'MVS',
         'max_depth': 2,
         'learning_rate': 0.2658641073071089,
         'max_bin': 897,
         'min_data_in_leaf': 162,
         'reg_lambda': 18.28415615971921,
         'subsample': 0.5705244926914805
        
}

# %%
ctb_oof = np.zeros(train.shape[0])
ctb_pred = np.zeros(test.shape[0])
ctb_importances = pd.DataFrame()

kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=CVSEED)
seed_list=[SEED, SEED+1, SEED+2]

for fold, (trn_idx, val_idx) in enumerate(kf.split(X=all_pseudo.iloc[:,:-1], y=all_pseudo[target])):
    print(f"===== fold {fold} =====")
    
    oof_idx = np.array([idx for idx in val_idx if idx < train.shape[0]])
    preds_idx = np.array([idx for idx in val_idx if idx >= train.shape[0]])
    
    X_train, y_train = all_pseudo.iloc[trn_idx, :-1], all_pseudo[target].iloc[trn_idx]
    #X_train = apply_noise_row(X_train)
    
    X_valid, y_valid = all_pseudo.iloc[oof_idx, :-1], all_pseudo[target].iloc[oof_idx]
    X_test = all_pseudo.iloc[preds_idx, :-1]
    
    # CatB
    start = time.time()
    
    for inseed in seed_list:
        ctb_params['random_state'] = inseed
    
        model = ctb.CatBoostRegressor(**ctb_params)
        model.fit(
            X_train, 
            y_train,
            eval_set=[(X_valid, y_valid)],
            use_best_model=True,
            early_stopping_rounds=EARLY_STOPPING_ROUNDS,
            verbose=VERBOSE
            
            )


        with open(f"lgb_model{fold}.pkl", 'wb') as f:
            pickle.dump(model, f)

        fi_tmp = pd.DataFrame()
        fi_tmp['feature'] = X_train.columns
        fi_tmp['importance'] = model.feature_importances_
        fi_tmp['fold'] = fold
        fi_tmp['seed'] = inseed
        ctb_importances = ctb_importances.append(fi_tmp)

        ctb_oof[oof_idx] += model.predict(X_valid) / len(seed_list)
        ctb_pred[preds_idx-train.shape[0]] += model.predict(X_test) / len(seed_list)
    
    elapsed = time.time() - start
    rmse = mean_squared_error(y_valid, ctb_oof[oof_idx], squared=False)
    print(f"fold {fold} - ctb rmse: {rmse:.6f}, elapsed time: {elapsed:.2f}sec\n")

        
print(f"oof ctb_rmse = {mean_squared_error(train[target], ctb_oof, squared=False)}")

np.save("ctb_oof.npy", ctb_oof)
np.save("ctb_pred.npy", ctb_pred)
# Out:
# ===== fold 0 =====
# 0:	learn: 0.5917516	test: 0.7391677	best: 0.7391677 (0)	total: 97.5ms	remaining: 32m 29s
# 1000:	learn: 0.5557708	test: 0.7127972	best: 0.7127972 (1000)	total: 27.4s	remaining: 8m 39s
# 2000:	learn: 0.5523142	test: 0.7112109	best: 0.7111887 (1974)	total: 54.6s	remaining: 8m 10s
# 3000:	learn: 0.5504647	test: 0.7107004	best: 0.7106938 (2982)	total: 1m 21s	remaining: 7m 42s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7106628593
# bestIteration = 3088
#
# Shrink model to first 3089 iterations.
# 0:	learn: 0.5917706	test: 0.7391380	best: 0.7391380 (0)	total: 28.7ms	remaining: 9m 34s
# 1000:	learn: 0.5557718	test: 0.7126465	best: 0.7126465 (1000)	total: 27.3s	remaining: 8m 38s
# 2000:	learn: 0.5523681	test: 0.7110791	best: 0.7110791 (2000)	total: 54s	remaining: 8m 5s
# 3000:	learn: 0.5505136	test: 0.7107397	best: 0.7107000 (2878)	total: 1m 20s	remaining: 7m 37s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7106924233
# bestIteration = 3055
#
# Shrink model to first 3056 iterations.
# 0:	learn: 0.5917403	test: 0.7391510	best: 0.7391510 (0)	total: 28.3ms	remaining: 9m 26s
# 1000:	learn: 0.5557697	test: 0.7127754	best: 0.7127599 (995)	total: 27.2s	remaining: 8m 36s
# 2000:	learn: 0.5522670	test: 0.7111526	best: 0.7111504 (1996)	total: 54.2s	remaining: 8m 7s
# 3000:	learn: 0.5505002	test: 0.7107311	best: 0.7107300 (2999)	total: 1m 21s	remaining: 7m 39s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7106925588
# bestIteration = 3080
#
# Shrink model to first 3081 iterations.
# fold 0 - ctb rmse: 0.710440, elapsed time: 270.16sec
#
# ===== fold 1 =====
# 0:	learn: 0.5921421	test: 0.7375194	best: 0.7375194 (0)	total: 28ms	remaining: 9m 19s
# 1000:	learn: 0.5561472	test: 0.7104977	best: 0.7104977 (1000)	total: 27.5s	remaining: 8m 41s
# 2000:	learn: 0.5527598	test: 0.7094276	best: 0.7094141 (1938)	total: 54.6s	remaining: 8m 11s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.708951946
# bestIteration = 2645
#
# Shrink model to first 2646 iterations.
# 0:	learn: 0.5921702	test: 0.7375411	best: 0.7375411 (0)	total: 28.9ms	remaining: 9m 37s
# 1000:	learn: 0.5561789	test: 0.7103924	best: 0.7103878 (997)	total: 27.3s	remaining: 8m 38s
# 2000:	learn: 0.5527587	test: 0.7090797	best: 0.7090737 (1982)	total: 54.3s	remaining: 8m 8s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7088414869
# bestIteration = 2403
#
# Shrink model to first 2404 iterations.
# 0:	learn: 0.5921446	test: 0.7375323	best: 0.7375323 (0)	total: 27.2ms	remaining: 9m 4s
# 1000:	learn: 0.5562199	test: 0.7105303	best: 0.7105167 (995)	total: 27.6s	remaining: 8m 43s
# 2000:	learn: 0.5526668	test: 0.7091040	best: 0.7091040 (2000)	total: 54.7s	remaining: 8m 11s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.708939203
# bestIteration = 2294
#
# Shrink model to first 2295 iterations.
# fold 1 - ctb rmse: 0.708676, elapsed time: 219.98sec
#
# ===== fold 2 =====
# 0:	learn: 0.5912020	test: 0.7465145	best: 0.7465145 (0)	total: 29ms	remaining: 9m 40s
# 1000:	learn: 0.5553263	test: 0.7182449	best: 0.7182449 (1000)	total: 27.3s	remaining: 8m 38s
# 2000:	learn: 0.5519693	test: 0.7164336	best: 0.7164259 (1991)	total: 55.1s	remaining: 8m 15s
# 3000:	learn: 0.5501582	test: 0.7158199	best: 0.7158139 (2986)	total: 1m 22s	remaining: 7m 47s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7156896223
# bestIteration = 3383
#
# Shrink model to first 3384 iterations.
# 0:	learn: 0.5912278	test: 0.7465718	best: 0.7465718 (0)	total: 27.1ms	remaining: 9m 1s
# 1000:	learn: 0.5554897	test: 0.7183428	best: 0.7183428 (1000)	total: 27.3s	remaining: 8m 38s
# 2000:	learn: 0.5520226	test: 0.7162698	best: 0.7162336 (1974)	total: 54.5s	remaining: 8m 10s
# 3000:	learn: 0.5501991	test: 0.7158789	best: 0.7158462 (2922)	total: 1m 21s	remaining: 7m 42s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7156369495
# bestIteration = 3614
#
# Shrink model to first 3615 iterations.
# 0:	learn: 0.5912044	test: 0.7465849	best: 0.7465849 (0)	total: 28.9ms	remaining: 9m 38s
# 1000:	learn: 0.5555050	test: 0.7184160	best: 0.7184160 (1000)	total: 27.1s	remaining: 8m 35s
# 2000:	learn: 0.5520728	test: 0.7163261	best: 0.7163249 (1996)	total: 54.4s	remaining: 8m 9s
# 3000:	learn: 0.5503073	test: 0.7158431	best: 0.7158284 (2888)	total: 1m 21s	remaining: 7m 42s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7157053991
# bestIteration = 3515
#
# Shrink model to first 3516 iterations.
# fold 2 - ctb rmse: 0.715433, elapsed time: 307.39sec
#
# ===== fold 3 =====
# 0:	learn: 0.5912616	test: 0.7479616	best: 0.7479616 (0)	total: 27.3ms	remaining: 9m 6s
# 1000:	learn: 0.5556124	test: 0.7198862	best: 0.7198862 (1000)	total: 27.9s	remaining: 8m 48s
# 2000:	learn: 0.5520300	test: 0.7181885	best: 0.7181885 (2000)	total: 55.4s	remaining: 8m 18s
# 3000:	learn: 0.5501937	test: 0.7177404	best: 0.7177302 (2960)	total: 1m 22s	remaining: 7m 45s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7176089469
# bestIteration = 3672
#
# Shrink model to first 3673 iterations.
# 0:	learn: 0.5912953	test: 0.7480332	best: 0.7480332 (0)	total: 29.5ms	remaining: 9m 49s
# 1000:	learn: 0.5554803	test: 0.7197666	best: 0.7197666 (1000)	total: 27.5s	remaining: 8m 42s
# 2000:	learn: 0.5520239	test: 0.7180669	best: 0.7180669 (2000)	total: 54.8s	remaining: 8m 12s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7177010845
# bestIteration = 2603
#
# Shrink model to first 2604 iterations.
# 0:	learn: 0.5912716	test: 0.7479778	best: 0.7479778 (0)	total: 31.3ms	remaining: 10m 25s
# 1000:	learn: 0.5555172	test: 0.7196877	best: 0.7196806 (995)	total: 27.3s	remaining: 8m 38s
# 2000:	learn: 0.5520549	test: 0.7182348	best: 0.7182295 (1998)	total: 54.5s	remaining: 8m 10s
# 3000:	learn: 0.5502066	test: 0.7177983	best: 0.7177879 (2971)	total: 1m 21s	remaining: 7m 42s
# 4000:	learn: 0.5488554	test: 0.7175456	best: 0.7175312 (3884)	total: 1m 48s	remaining: 7m 14s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7175312065
# bestIteration = 3884
#
# Shrink model to first 3885 iterations.
# fold 3 - ctb rmse: 0.717349, elapsed time: 297.60sec
#
# ===== fold 4 =====
# 0:	learn: 0.5913182	test: 0.7463011	best: 0.7463011 (0)	total: 28.2ms	remaining: 9m 24s
# 1000:	learn: 0.5553443	test: 0.7198763	best: 0.7198763 (1000)	total: 27.3s	remaining: 8m 38s
# 2000:	learn: 0.5519078	test: 0.7183240	best: 0.7183108 (1993)	total: 54.6s	remaining: 8m 11s
# 3000:	learn: 0.5501353	test: 0.7178183	best: 0.7178183 (3000)	total: 1m 21s	remaining: 7m 43s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7177180261
# bestIteration = 3217
#
# Shrink model to first 3218 iterations.
# 0:	learn: 0.5913344	test: 0.7462986	best: 0.7462986 (0)	total: 26.2ms	remaining: 8m 43s
# 1000:	learn: 0.5553245	test: 0.7199586	best: 0.7199586 (1000)	total: 27.2s	remaining: 8m 36s
# 2000:	learn: 0.5518660	test: 0.7181560	best: 0.7181360 (1994)	total: 54.3s	remaining: 8m 8s
# 3000:	learn: 0.5500585	test: 0.7174548	best: 0.7174467 (2997)	total: 1m 21s	remaining: 7m 39s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7172989054
# bestIteration = 3379
#
# Shrink model to first 3380 iterations.
# 0:	learn: 0.5913212	test: 0.7462700	best: 0.7462700 (0)	total: 29.9ms	remaining: 9m 58s
# 1000:	learn: 0.5554926	test: 0.7200380	best: 0.7200380 (1000)	total: 27.2s	remaining: 8m 36s
# 2000:	learn: 0.5519642	test: 0.7183828	best: 0.7183811 (1999)	total: 54.3s	remaining: 8m 8s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7180740663
# bestIteration = 2535
#
# Shrink model to first 2536 iterations.
# fold 4 - ctb rmse: 0.717448, elapsed time: 267.95sec
#
# ===== fold 5 =====
# 0:	learn: 0.5910258	test: 0.7497858	best: 0.7497858 (0)	total: 28.3ms	remaining: 9m 25s
# 1000:	learn: 0.5550787	test: 0.7240477	best: 0.7240477 (1000)	total: 27.6s	remaining: 8m 44s
# 2000:	learn: 0.5516181	test: 0.7223856	best: 0.7223856 (2000)	total: 54.7s	remaining: 8m 12s
# 3000:	learn: 0.5498274	test: 0.7218533	best: 0.7218471 (2992)	total: 1m 21s	remaining: 7m 44s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7217247517
# bestIteration = 3594
#
# Shrink model to first 3595 iterations.
# 0:	learn: 0.5910616	test: 0.7497891	best: 0.7497891 (0)	total: 25.9ms	remaining: 8m 37s
# 1000:	learn: 0.5549882	test: 0.7239542	best: 0.7239522 (999)	total: 27.5s	remaining: 8m 41s
# 2000:	learn: 0.5516490	test: 0.7222671	best: 0.7222642 (1976)	total: 54.5s	remaining: 8m 10s
# 3000:	learn: 0.5498524	test: 0.7218301	best: 0.7218283 (2999)	total: 1m 21s	remaining: 7m 41s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7217012584
# bestIteration = 3672
#
# Shrink model to first 3673 iterations.
# 0:	learn: 0.5910360	test: 0.7497768	best: 0.7497768 (0)	total: 26.8ms	remaining: 8m 55s
# 1000:	learn: 0.5550163	test: 0.7239899	best: 0.7239899 (1000)	total: 27.4s	remaining: 8m 39s
# 2000:	learn: 0.5515730	test: 0.7222972	best: 0.7222972 (2000)	total: 54.5s	remaining: 8m 10s
# 3000:	learn: 0.5498178	test: 0.7220002	best: 0.7219802 (2990)	total: 1m 21s	remaining: 7m 40s
# 4000:	learn: 0.5485116	test: 0.7219204	best: 0.7218865 (3867)	total: 1m 48s	remaining: 7m 12s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7218380135
# bestIteration = 4282
#
# Shrink model to first 4283 iterations.
# fold 5 - ctb rmse: 0.721498, elapsed time: 334.71sec
#
# ===== fold 6 =====
# 0:	learn: 0.5912178	test: 0.7473592	best: 0.7473592 (0)	total: 28ms	remaining: 9m 19s
# 1000:	learn: 0.5554087	test: 0.7206974	best: 0.7206974 (1000)	total: 27.3s	remaining: 8m 38s
# 2000:	learn: 0.5519276	test: 0.7188818	best: 0.7188762 (1992)	total: 54.2s	remaining: 8m 7s
# 3000:	learn: 0.5500927	test: 0.7183900	best: 0.7183868 (2999)	total: 1m 21s	remaining: 7m 41s
# 4000:	learn: 0.5487692	test: 0.7182053	best: 0.7181748 (3842)	total: 1m 48s	remaining: 7m 14s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7181747666
# bestIteration = 3842
#
# Shrink model to first 3843 iterations.
# 0:	learn: 0.5912424	test: 0.7472637	best: 0.7472637 (0)	total: 28ms	remaining: 9m 20s
# 1000:	learn: 0.5553099	test: 0.7205185	best: 0.7205135 (998)	total: 27.1s	remaining: 8m 34s
# 2000:	learn: 0.5518346	test: 0.7189229	best: 0.7188896 (1964)	total: 54.1s	remaining: 8m 6s
# 3000:	learn: 0.5500869	test: 0.7185070	best: 0.7184943 (2950)	total: 1m 20s	remaining: 7m 38s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7183514517
# bestIteration = 3676
#
# Shrink model to first 3677 iterations.
# 0:	learn: 0.5912112	test: 0.7472540	best: 0.7472540 (0)	total: 29.2ms	remaining: 9m 44s
# 1000:	learn: 0.5552977	test: 0.7205238	best: 0.7205238 (1000)	total: 27.4s	remaining: 8m 39s
# 2000:	learn: 0.5518407	test: 0.7187518	best: 0.7187518 (2000)	total: 54.5s	remaining: 8m 9s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7184228365
# bestIteration = 2625
#
# Shrink model to first 2626 iterations.
# fold 6 - ctb rmse: 0.718051, elapsed time: 295.55sec
#
# ===== fold 7 =====
# 0:	learn: 0.5916455	test: 0.7424499	best: 0.7424499 (0)	total: 27.4ms	remaining: 9m 8s
# 1000:	learn: 0.5556805	test: 0.7163800	best: 0.7163800 (1000)	total: 27.2s	remaining: 8m 36s
# 2000:	learn: 0.5522427	test: 0.7148960	best: 0.7148960 (2000)	total: 54.1s	remaining: 8m 6s
# 3000:	learn: 0.5504747	test: 0.7145701	best: 0.7145290 (2870)	total: 1m 20s	remaining: 7m 36s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7144845624
# bestIteration = 3131
#
# Shrink model to first 3132 iterations.
# 0:	learn: 0.5916506	test: 0.7425116	best: 0.7425116 (0)	total: 29.9ms	remaining: 9m 57s
# 1000:	learn: 0.5557304	test: 0.7164556	best: 0.7164510 (998)	total: 27.2s	remaining: 8m 37s
# 2000:	learn: 0.5522430	test: 0.7147227	best: 0.7147227 (2000)	total: 54.5s	remaining: 8m 10s
# 3000:	learn: 0.5504087	test: 0.7144889	best: 0.7144597 (2878)	total: 1m 21s	remaining: 7m 42s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7144597471
# bestIteration = 2878
#
# Shrink model to first 2879 iterations.
# 0:	learn: 0.5916259	test: 0.7424599	best: 0.7424599 (0)	total: 28.6ms	remaining: 9m 32s
# 1000:	learn: 0.5555555	test: 0.7161414	best: 0.7161368 (998)	total: 27.1s	remaining: 8m 35s
# 2000:	learn: 0.5521525	test: 0.7146038	best: 0.7146038 (2000)	total: 54s	remaining: 8m 6s
# 3000:	learn: 0.5503966	test: 0.7142845	best: 0.7142707 (2972)	total: 1m 20s	remaining: 7m 36s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7139868524
# bestIteration = 3607
#
# Shrink model to first 3608 iterations.
# fold 7 - ctb rmse: 0.714061, elapsed time: 279.74sec
#
# ===== fold 8 =====
# 0:	learn: 0.5916258	test: 0.7452393	best: 0.7452393 (0)	total: 28ms	remaining: 9m 19s
# 1000:	learn: 0.5556985	test: 0.7181473	best: 0.7181472 (999)	total: 27.3s	remaining: 8m 37s
# 2000:	learn: 0.5523103	test: 0.7166864	best: 0.7166793 (1997)	total: 54.2s	remaining: 8m 7s
# 3000:	learn: 0.5504983	test: 0.7161732	best: 0.7161684 (2996)	total: 1m 21s	remaining: 7m 39s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7160466372
# bestIteration = 3409
#
# Shrink model to first 3410 iterations.
# 0:	learn: 0.5916382	test: 0.7452660	best: 0.7452660 (0)	total: 26.9ms	remaining: 8m 57s
# 1000:	learn: 0.5557550	test: 0.7183279	best: 0.7183279 (1000)	total: 27.4s	remaining: 8m 39s
# 2000:	learn: 0.5522901	test: 0.7166142	best: 0.7166065 (1989)	total: 54.6s	remaining: 8m 10s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7162723057
# bestIteration = 2555
#
# Shrink model to first 2556 iterations.
# 0:	learn: 0.5916119	test: 0.7452464	best: 0.7452464 (0)	total: 40.1ms	remaining: 13m 21s
# 1000:	learn: 0.5557820	test: 0.7182255	best: 0.7182255 (1000)	total: 27.1s	remaining: 8m 34s
# 2000:	learn: 0.5523295	test: 0.7166796	best: 0.7166785 (1999)	total: 54.2s	remaining: 8m 7s
# 3000:	learn: 0.5505247	test: 0.7161181	best: 0.7161092 (2980)	total: 1m 21s	remaining: 7m 40s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7160461289
# bestIteration = 3459
#
# Shrink model to first 3460 iterations.
# fold 8 - ctb rmse: 0.715871, elapsed time: 275.53sec
#
# ===== fold 9 =====
# 0:	learn: 0.5911165	test: 0.7479151	best: 0.7479151 (0)	total: 28.2ms	remaining: 9m 23s
# 1000:	learn: 0.5551952	test: 0.7210432	best: 0.7210403 (997)	total: 26.8s	remaining: 8m 29s
# 2000:	learn: 0.5517297	test: 0.7192974	best: 0.7192885 (1998)	total: 54.6s	remaining: 8m 10s
# 3000:	learn: 0.5499357	test: 0.7189280	best: 0.7189280 (3000)	total: 1m 21s	remaining: 7m 42s
# 4000:	learn: 0.5486395	test: 0.7186629	best: 0.7186500 (3935)	total: 1m 48s	remaining: 7m 13s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7185911308
# bestIteration = 4225
#
# Shrink model to first 4226 iterations.
# 0:	learn: 0.5910945	test: 0.7479467	best: 0.7479467 (0)	total: 29.5ms	remaining: 9m 49s
# 1000:	learn: 0.5551436	test: 0.7207262	best: 0.7207262 (1000)	total: 27.1s	remaining: 8m 34s
# 2000:	learn: 0.5517072	test: 0.7192662	best: 0.7192499 (1970)	total: 54.1s	remaining: 8m 6s
# 3000:	learn: 0.5499229	test: 0.7187750	best: 0.7187744 (2999)	total: 1m 21s	remaining: 7m 40s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7186768573
# bestIteration = 3314
#
# Shrink model to first 3315 iterations.
# 0:	learn: 0.5910750	test: 0.7478863	best: 0.7478863 (0)	total: 26.7ms	remaining: 8m 53s
# 1000:	learn: 0.5551174	test: 0.7208845	best: 0.7208771 (984)	total: 27.7s	remaining: 8m 46s
# 2000:	learn: 0.5516291	test: 0.7192841	best: 0.7192834 (1975)	total: 55s	remaining: 8m 14s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7190630722
# bestIteration = 2409
#
# Shrink model to first 2410 iterations.
# fold 9 - ctb rmse: 0.718506, elapsed time: 290.64sec
#
# oof ctb_rmse = 0.7157408730820433

# %% [markdown]
# # OOF predictions

# %%
plt.plot(train[target], train[target])
plt.scatter(train[target], ctb_oof)

# %% [markdown]
# # Features importances

# %%
order = list(ctb_importances.groupby('feature').mean().sort_values('importance', ascending=False).index)

fig = plt.figure(figsize=(16, 16), tight_layout=True)
sns.barplot(x="importance", y="feature", data=ctb_importances.groupby('feature').mean().reset_index(), order=order)
plt.title("CatB feature importances")
# Out:
# Text(0.5, 1.0, 'CatB feature importances')

# %% [markdown]
# # Submission

# %%
submission[target] = ctb_pred
submission.to_csv("submission.csv", index=False)

submission
# Out:
#             id    target
# 0            0  8.085200
# 1            5  8.399843
# 2           15  8.373043
# 3           16  8.494401
# 4           17  8.155389
# ...        ...       ...
# 199995  499987  8.037608
# 199996  499990  8.512640
# 199997  499991  8.543486
# 199998  499994  8.234455
# 199999  499995  7.955027
#
# [200000 rows x 2 columns]
