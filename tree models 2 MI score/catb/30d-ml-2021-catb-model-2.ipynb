# %%
# Familiar imports
import numpy as np
import pandas as pd
import random
import os
import time
import pickle
from pathlib import Path

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

from scipy.optimize import minimize

#import lightgbm as lgb
#import xgboost as xgb
import catboost as ctb

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # Parameters

# %%
target = 'target'

DEBUG = False

if DEBUG:
    N_ESTIMATORS = 1
    N_SPLITS = 2
    SEED = 17
    CVSEED = 17
    EARLY_STOPPING_ROUNDS = 1
    VERBOSE = 100
    #N_ITERS = 2
else:
    N_SPLITS = 10
    N_ESTIMATORS = 20000
    EARLY_STOPPING_ROUNDS = 200
    VERBOSE = 1000
    SEED = 17
    CVSEED = 17
    #N_ITERS = 10

# %%
def set_seed(seed=17):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
set_seed(SEED)

# %% [markdown]
# # Load data

# %%
# Load the training data
train = pd.read_csv("../input/30-days-of-ml/train.csv")
test = pd.read_csv("../input/30-days-of-ml/test.csv")
submission = pd.read_csv("../input/30-days-of-ml/sample_submission.csv")

# Preview the data
train.head()
# Out:
#    id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont5     cont6  \
# 0   1    B    B    B    C    B    B    A    E    C  ...  0.400361  0.160266
# 1   2    B    B    A    A    B    D    A    F    A  ...  0.533087  0.558922
# 2   3    A    A    A    C    B    D    A    D    A  ...  0.650609  0.375348
# 3   4    B    B    A    C    B    D    A    E    C  ...  0.668980  0.239061
# 4   6    A    A    A    C    B    D    A    E    A  ...  0.686964  0.420667
#
#       cont7     cont8     cont9    cont10    cont11    cont12    cont13  \
# 0  0.310921  0.389470  0.267559  0.237281  0.377873  0.322401  0.869850
# 1  0.516294  0.594928  0.341439  0.906013  0.921701  0.261975  0.465083
# 2  0.902567  0.555205  0.843531  0.748809  0.620126  0.541474  0.763846
# 3  0.732948  0.679618  0.574844  0.346010  0.714610  0.540150  0.280682
# 4  0.648182  0.684501  0.956692  1.000773  0.776742  0.625849  0.250823
#
#      target
# 0  8.113634
# 1  8.481233
# 2  8.364351
# 3  8.049253
# 4  7.972260
#
# [5 rows x 26 columns]

# %%
# Low MI scores
for pp in ["cat2","cat3","cat4","cat6"]:
    train.pop(pp)
    test.pop(pp)
train.head()
# Out:
#    id cat0 cat1 cat5 cat7 cat8 cat9     cont0     cont1     cont2  ...  \
# 0   1    B    B    B    E    C    N  0.201470 -0.014822  0.669699  ...
# 1   2    B    B    D    F    A    O  0.743068  0.367411  1.021605  ...
# 2   3    A    A    D    D    A    F  0.742708  0.310383 -0.012673  ...
# 3   4    B    B    D    E    C    K  0.429551  0.620998  0.577942  ...
# 4   6    A    A    D    E    A    N  1.058291  0.367492 -0.052389  ...
#
#       cont5     cont6     cont7     cont8     cont9    cont10    cont11  \
# 0  0.400361  0.160266  0.310921  0.389470  0.267559  0.237281  0.377873
# 1  0.533087  0.558922  0.516294  0.594928  0.341439  0.906013  0.921701
# 2  0.650609  0.375348  0.902567  0.555205  0.843531  0.748809  0.620126
# 3  0.668980  0.239061  0.732948  0.679618  0.574844  0.346010  0.714610
# 4  0.686964  0.420667  0.648182  0.684501  0.956692  1.000773  0.776742
#
#      cont12    cont13    target
# 0  0.322401  0.869850  8.113634
# 1  0.261975  0.465083  8.481233
# 2  0.541474  0.763846  8.364351
# 3  0.540150  0.280682  8.049253
# 4  0.625849  0.250823  7.972260
#
# [5 rows x 22 columns]

# %%
# Separate target from features
y = train['target']
features = train.drop(['id','target'], axis=1)

# Preview features
features.head()
# Out:
#   cat0 cat1 cat5 cat7 cat8 cat9     cont0     cont1     cont2     cont3  \
# 0    B    B    B    E    C    N  0.201470 -0.014822  0.669699  0.136278
# 1    B    B    D    F    A    O  0.743068  0.367411  1.021605  0.365798
# 2    A    A    D    D    A    F  0.742708  0.310383 -0.012673  0.576957
# 3    B    B    D    E    C    K  0.429551  0.620998  0.577942  0.280610
# 4    A    A    D    E    A    N  1.058291  0.367492 -0.052389  0.232407
#
#       cont4     cont5     cont6     cont7     cont8     cont9    cont10  \
# 0  0.610706  0.400361  0.160266  0.310921  0.389470  0.267559  0.237281
# 1  0.276853  0.533087  0.558922  0.516294  0.594928  0.341439  0.906013
# 2  0.285074  0.650609  0.375348  0.902567  0.555205  0.843531  0.748809
# 3  0.284667  0.668980  0.239061  0.732948  0.679618  0.574844  0.346010
# 4  0.287595  0.686964  0.420667  0.648182  0.684501  0.956692  1.000773
#
#      cont11    cont12    cont13
# 0  0.377873  0.322401  0.869850
# 1  0.921701  0.261975  0.465083
# 2  0.620126  0.541474  0.763846
# 3  0.714610  0.540150  0.280682
# 4  0.776742  0.625849  0.250823

# %% [markdown]
# # Preprocessing

# %%
# List of categorical columns
object_cols = [col for col in features.columns if 'cat' in col]

# ordinal-encode categorical columns
X = features.copy()
X_test = test.drop(['id'], axis=1).copy()
ordinal_encoder = OrdinalEncoder()
X[object_cols] = ordinal_encoder.fit_transform(features[object_cols])
X_test[object_cols] = ordinal_encoder.transform(test[object_cols])

# Preview the ordinal-encoded features
X.head()
# Out:
#    cat0  cat1  cat5  cat7  cat8  cat9     cont0     cont1     cont2     cont3  \
# 0   1.0   1.0   1.0   4.0   2.0  13.0  0.201470 -0.014822  0.669699  0.136278
# 1   1.0   1.0   3.0   5.0   0.0  14.0  0.743068  0.367411  1.021605  0.365798
# 2   0.0   0.0   3.0   3.0   0.0   5.0  0.742708  0.310383 -0.012673  0.576957
# 3   1.0   1.0   3.0   4.0   2.0  10.0  0.429551  0.620998  0.577942  0.280610
# 4   0.0   0.0   3.0   4.0   0.0  13.0  1.058291  0.367492 -0.052389  0.232407
#
#       cont4     cont5     cont6     cont7     cont8     cont9    cont10  \
# 0  0.610706  0.400361  0.160266  0.310921  0.389470  0.267559  0.237281
# 1  0.276853  0.533087  0.558922  0.516294  0.594928  0.341439  0.906013
# 2  0.285074  0.650609  0.375348  0.902567  0.555205  0.843531  0.748809
# 3  0.284667  0.668980  0.239061  0.732948  0.679618  0.574844  0.346010
# 4  0.287595  0.686964  0.420667  0.648182  0.684501  0.956692  1.000773
#
#      cont11    cont12    cont13
# 0  0.377873  0.322401  0.869850
# 1  0.921701  0.261975  0.465083
# 2  0.620126  0.541474  0.763846
# 3  0.714610  0.540150  0.280682
# 4  0.776742  0.625849  0.250823

# %%
'''
# List of categorical columns
object_cols = [col for col in features.columns if 'cat' in col]

# one-hot-encode categorical columns
X = features.copy()
X_test = test.drop(['id'], axis=1).copy()

oh_encoder = OneHotEncoder(sparse=False, handle_unknown="ignore")
X_ohe = oh_encoder.fit_transform(features[object_cols])
X_test_ohe = oh_encoder.transform(test[object_cols])

X_ohe = pd.DataFrame(X_ohe, columns=[f"ohe_{i}" for i in range(X_ohe.shape[1])])
X_test_ohe = pd.DataFrame(X_test_ohe, columns=[f"ohe_{i}" for i in range(X_test_ohe.shape[1])])

X = pd.concat([X, X_ohe], axis=1)
X_test = pd.concat([X_test, X_test_ohe], axis=1)
X = X.drop(object_cols, axis=1)
X_test = X_test.drop(object_cols, axis=1)
    
# Preview the one-hot-encoded features
X.head()
'''
# Out:
# '\n# List of categorical columns\nobject_cols = [col for col in features.columns if \'cat\' in col]\n\n# one-hot-encode categorical columns\nX = features.copy()\nX_test = test.drop([\'id\'], axis=1).copy()\n\noh_encoder = OneHotEncoder(sparse=False, handle_unknown="ignore")\nX_ohe = oh_encoder.fit_transform(features[object_cols])\nX_test_ohe = oh_encoder.transform(test[object_cols])\n\nX_ohe = pd.DataFrame(X_ohe, columns=[f"ohe_{i}" for i in range(X_ohe.shape[1])])\nX_test_ohe = pd.DataFrame(X_test_ohe, columns=[f"ohe_{i}" for i in range(X_test_ohe.shape[1])])\n\nX = pd.concat([X, X_ohe], axis=1)\nX_test = pd.concat([X_test, X_test_ohe], axis=1)\nX = X.drop(object_cols, axis=1)\nX_test = X_test.drop(object_cols, axis=1)\n    \n# Preview the one-hot-encoded features\nX.head()\n'

# %%
scale_features = [col for col in features.columns if 'cont' in col]

ss = StandardScaler()
X[scale_features] = ss.fit_transform(features[scale_features])
X_test[scale_features] = ss.transform(test[scale_features])

# %%
# Swap noise

# Random
def apply_noise_rn(df, p=.75):
    should_not_swap = np.random.binomial(1, p, df.shape)
    corrupted_df = df.where(should_not_swap == 1, np.random.permutation(df))
    return corrupted_df

# Row-wise
def apply_noise_row(df, p=.75):
    should_not_swap = np.zeros(df.shape)
    for i in range(df.shape[0]):
        for j in np.random.choice(df.shape[1],int(p*df.shape[1]),replace=False):
            should_not_swap[i,j]=1 
    corrupted_df = df.where(should_not_swap == 1, np.random.permutation(df))
    return corrupted_df

# %% [markdown]
# # Pseudo Label

# %%
pseudo = pd.read_csv("../input/30-days-pseudo/submission.csv")[target]
train_pseudo = pd.concat([X, y], axis=1)
test_pseudo = pd.concat([X_test, pseudo], axis=1)
all_pseudo = pd.concat([train_pseudo, test_pseudo]).reset_index(drop=True)

# %% [markdown]
# # CatB

# %%
ctb_params = {
        'bootstrap_type': 'Poisson',
            'loss_function': 'RMSE',
            'eval_metric': 'RMSE',
          'task_type': 'GPU',
         'n_estimators':N_ESTIMATORS,

            'max_depth': 2,
         'learning_rate': 0.03816667154616651,
         'max_bin': 709,
         'min_data_in_leaf': 159,
         'reg_lambda': 30.922021895077272,
         'subsample': 0.9998995160334373
        
}

# %%
ctb_oof = np.zeros(train.shape[0])
ctb_pred = np.zeros(test.shape[0])
ctb_importances = pd.DataFrame()

kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=CVSEED)
seed_list=[SEED, SEED+1, SEED+2]

for fold, (trn_idx, val_idx) in enumerate(kf.split(X=all_pseudo.iloc[:,:-1], y=all_pseudo[target])):
    print(f"===== fold {fold} =====")
    
    oof_idx = np.array([idx for idx in val_idx if idx < train.shape[0]])
    preds_idx = np.array([idx for idx in val_idx if idx >= train.shape[0]])
    
    X_train, y_train = all_pseudo.iloc[trn_idx, :-1], all_pseudo[target].iloc[trn_idx]
    #X_train = apply_noise_row(X_train)
    
    X_valid, y_valid = all_pseudo.iloc[oof_idx, :-1], all_pseudo[target].iloc[oof_idx]
    X_test = all_pseudo.iloc[preds_idx, :-1]
    
    # CatB
    start = time.time()
    
    for inseed in seed_list:
        ctb_params['random_state'] = inseed
    
        model = ctb.CatBoostRegressor(**ctb_params)
        model.fit(
            X_train, 
            y_train,
            eval_set=[(X_valid, y_valid)],
            use_best_model=True,
            early_stopping_rounds=EARLY_STOPPING_ROUNDS,
            verbose=VERBOSE
            
            )


        with open(f"lgb_model{fold}.pkl", 'wb') as f:
            pickle.dump(model, f)

        fi_tmp = pd.DataFrame()
        fi_tmp['feature'] = X_train.columns
        fi_tmp['importance'] = model.feature_importances_
        fi_tmp['fold'] = fold
        fi_tmp['seed'] = inseed
        ctb_importances = ctb_importances.append(fi_tmp)

        ctb_oof[oof_idx] += model.predict(X_valid) / len(seed_list)
        ctb_pred[preds_idx-train.shape[0]] += model.predict(X_test) / len(seed_list)
    
    elapsed = time.time() - start
    rmse = mean_squared_error(y_valid, ctb_oof[oof_idx], squared=False)
    print(f"fold {fold} - ctb rmse: {rmse:.6f}, elapsed time: {elapsed:.2f}sec\n")

        
print(f"oof ctb_rmse = {mean_squared_error(train[target], ctb_oof, squared=False)}")

np.save("ctb_oof.npy", ctb_oof)
np.save("ctb_pred.npy", ctb_pred)
# Out:
# ===== fold 0 =====
# 0:	learn: 0.5928378	test: 0.7406027	best: 0.7406027 (0)	total: 13.4ms	remaining: 4m 28s
# 1000:	learn: 0.5694766	test: 0.7222608	best: 0.7222608 (1000)	total: 5.98s	remaining: 1m 53s
# 2000:	learn: 0.5646204	test: 0.7188569	best: 0.7188569 (2000)	total: 11.3s	remaining: 1m 41s
# 3000:	learn: 0.5615020	test: 0.7167443	best: 0.7167443 (2999)	total: 16.4s	remaining: 1m 32s
# 4000:	learn: 0.5594597	test: 0.7153632	best: 0.7153632 (4000)	total: 21.7s	remaining: 1m 26s
# 5000:	learn: 0.5579327	test: 0.7143130	best: 0.7143130 (5000)	total: 26.8s	remaining: 1m 20s
# 6000:	learn: 0.5567765	test: 0.7135360	best: 0.7135360 (6000)	total: 32.3s	remaining: 1m 15s
# 7000:	learn: 0.5559006	test: 0.7129737	best: 0.7129729 (6999)	total: 38.1s	remaining: 1m 10s
# 8000:	learn: 0.5551825	test: 0.7125342	best: 0.7125342 (7999)	total: 43.5s	remaining: 1m 5s
# 9000:	learn: 0.5545774	test: 0.7122289	best: 0.7122289 (9000)	total: 48.6s	remaining: 59.3s
# 10000:	learn: 0.5540471	test: 0.7119513	best: 0.7119511 (9998)	total: 53.9s	remaining: 53.9s
# 11000:	learn: 0.5535834	test: 0.7117459	best: 0.7117459 (11000)	total: 59s	remaining: 48.2s
# 12000:	learn: 0.5531680	test: 0.7115574	best: 0.7115574 (12000)	total: 1m 4s	remaining: 42.9s
# 13000:	learn: 0.5527947	test: 0.7113723	best: 0.7113723 (13000)	total: 1m 10s	remaining: 37.8s
# 14000:	learn: 0.5524467	test: 0.7112054	best: 0.7112054 (14000)	total: 1m 15s	remaining: 32.4s
# 15000:	learn: 0.5521353	test: 0.7110897	best: 0.7110897 (15000)	total: 1m 20s	remaining: 26.9s
# 16000:	learn: 0.5518480	test: 0.7109988	best: 0.7109986 (15993)	total: 1m 25s	remaining: 21.5s
# 17000:	learn: 0.5515779	test: 0.7109075	best: 0.7109068 (16995)	total: 1m 30s	remaining: 16s
# 18000:	learn: 0.5513256	test: 0.7108374	best: 0.7108374 (18000)	total: 1m 36s	remaining: 10.7s
# 19000:	learn: 0.5510849	test: 0.7107557	best: 0.7107557 (19000)	total: 1m 42s	remaining: 5.36s
# 19999:	learn: 0.5508608	test: 0.7106858	best: 0.7106857 (19998)	total: 1m 47s	remaining: 0us
# bestTest = 0.710685724
# bestIteration = 19998
# Shrink model to first 19999 iterations.
# 0:	learn: 0.5928388	test: 0.7406028	best: 0.7406028 (0)	total: 6.03ms	remaining: 2m
# 1000:	learn: 0.5694373	test: 0.7222300	best: 0.7222300 (1000)	total: 5.04s	remaining: 1m 35s
# 2000:	learn: 0.5646376	test: 0.7188406	best: 0.7188406 (2000)	total: 10.5s	remaining: 1m 34s
# 3000:	learn: 0.5615230	test: 0.7167159	best: 0.7167159 (3000)	total: 15.6s	remaining: 1m 28s
# 4000:	learn: 0.5594807	test: 0.7153095	best: 0.7153092 (3999)	total: 21s	remaining: 1m 24s
# 5000:	learn: 0.5579521	test: 0.7142680	best: 0.7142680 (5000)	total: 26.6s	remaining: 1m 19s
# 6000:	learn: 0.5568371	test: 0.7135295	best: 0.7135295 (6000)	total: 32s	remaining: 1m 14s
# 7000:	learn: 0.5559455	test: 0.7129709	best: 0.7129709 (7000)	total: 37s	remaining: 1m 8s
# 8000:	learn: 0.5552226	test: 0.7125545	best: 0.7125545 (8000)	total: 42.3s	remaining: 1m 3s
# 9000:	learn: 0.5545975	test: 0.7122287	best: 0.7122269 (8995)	total: 47.3s	remaining: 57.8s
# 10000:	learn: 0.5540774	test: 0.7119707	best: 0.7119706 (9999)	total: 52.7s	remaining: 52.7s
# 11000:	learn: 0.5536124	test: 0.7117463	best: 0.7117454 (10998)	total: 58.4s	remaining: 47.7s
# 12000:	learn: 0.5531896	test: 0.7115591	best: 0.7115572 (11986)	total: 1m 3s	remaining: 42.5s
# 13000:	learn: 0.5528211	test: 0.7113958	best: 0.7113958 (13000)	total: 1m 8s	remaining: 37s
# 14000:	learn: 0.5524772	test: 0.7112887	best: 0.7112875 (13819)	total: 1m 13s	remaining: 31.7s
# 15000:	learn: 0.5521559	test: 0.7111532	best: 0.7111520 (14983)	total: 1m 19s	remaining: 26.4s
# 16000:	learn: 0.5518653	test: 0.7110359	best: 0.7110359 (16000)	total: 1m 24s	remaining: 21s
# 17000:	learn: 0.5516003	test: 0.7109623	best: 0.7109618 (16975)	total: 1m 30s	remaining: 15.9s
# 18000:	learn: 0.5513531	test: 0.7109013	best: 0.7109004 (17945)	total: 1m 35s	remaining: 10.6s
# 19000:	learn: 0.5511099	test: 0.7108375	best: 0.7108368 (18961)	total: 1m 40s	remaining: 5.29s
# 19999:	learn: 0.5508830	test: 0.7107717	best: 0.7107702 (19996)	total: 1m 45s	remaining: 0us
# bestTest = 0.7107702129
# bestIteration = 19996
# Shrink model to first 19997 iterations.
# 0:	learn: 0.5928382	test: 0.7406052	best: 0.7406052 (0)	total: 6.03ms	remaining: 2m
# 1000:	learn: 0.5694096	test: 0.7222330	best: 0.7222330 (1000)	total: 4.97s	remaining: 1m 34s
# 2000:	learn: 0.5646246	test: 0.7189329	best: 0.7189329 (2000)	total: 10.4s	remaining: 1m 33s
# 3000:	learn: 0.5615212	test: 0.7168183	best: 0.7168183 (3000)	total: 16.1s	remaining: 1m 31s
# 4000:	learn: 0.5594284	test: 0.7153578	best: 0.7153578 (4000)	total: 21.6s	remaining: 1m 26s
# 5000:	learn: 0.5579899	test: 0.7143813	best: 0.7143813 (5000)	total: 26.8s	remaining: 1m 20s
# 6000:	learn: 0.5568620	test: 0.7136704	best: 0.7136704 (5999)	total: 32.2s	remaining: 1m 15s
# 7000:	learn: 0.5559176	test: 0.7130776	best: 0.7130773 (6998)	total: 37.2s	remaining: 1m 9s
# 8000:	learn: 0.5551988	test: 0.7126410	best: 0.7126410 (8000)	total: 42.7s	remaining: 1m 4s
# 9000:	learn: 0.5545686	test: 0.7123067	best: 0.7123054 (8988)	total: 48.4s	remaining: 59.1s
# 10000:	learn: 0.5540519	test: 0.7120153	best: 0.7120144 (9999)	total: 53.8s	remaining: 53.8s
# 11000:	learn: 0.5535939	test: 0.7117960	best: 0.7117956 (10996)	total: 58.9s	remaining: 48.2s
# 12000:	learn: 0.5531721	test: 0.7116188	best: 0.7116188 (12000)	total: 1m 4s	remaining: 42.8s
# 13000:	learn: 0.5527999	test: 0.7114678	best: 0.7114665 (12991)	total: 1m 9s	remaining: 37.3s
# 14000:	learn: 0.5524567	test: 0.7113461	best: 0.7113449 (13990)	total: 1m 14s	remaining: 31.9s
# 15000:	learn: 0.5521500	test: 0.7112447	best: 0.7112437 (14997)	total: 1m 20s	remaining: 26.8s
# 16000:	learn: 0.5518639	test: 0.7111458	best: 0.7111456 (15999)	total: 1m 25s	remaining: 21.4s
# 17000:	learn: 0.
	total: 1m 25s	remaining: 21.4s
# 17000:	learn: 0.5519349	test: 0.7090064	best: 0.7090063 (16999)	total: 1m 30s	remaining: 16s
# 18000:	learn: 0.5516885	test: 0.7089375	best: 0.7089362 (17986)	total: 1m 35s	remaining: 10.6s
# 19000:	learn: 0.5514545	test: 0.7088832	best: 0.7088817 (18990)	total: 1m 40s	remaining: 5.3s
# 19999:	learn: 0.5512319	test: 0.7088520	best: 0.7088499 (19952)	total: 1m 46s	remaining: 0us
# bestTest = 0.7088498701
# bestIteration = 19952
# Shrink model to first 19953 iterations.
# fold 1 - ctb rmse: 0.708830, elapsed time: 300.42sec
#
# ===== fold 2 =====
# 0:	learn: 0.5923391	test: 0.7477306	best: 0.7477306 (0)	total: 5.96ms	remaining: 1m 59s
# 1000:	learn: 0.5690177	test: 0.7291136	best: 0.7291136 (1000)	total: 4.84s	remaining: 1m 31s
# 2000:	learn: 0.5642325	test: 0.7251676	best: 0.7251676 (2000)	total: 10.3s	remaining: 1m 32s
# 3000:	learn: 0.5610750	test: 0.7227059	best: 0.7227059 (3000)	total: 15.4s	remaining: 1m 27s
# 4000:	learn: 0.5590270	test: 0.7211748	best: 0.7211748 (4000)	total: 20.7s	remaining: 1m 22s
# 5000:	learn: 0.5575050	test: 0.7200183	best: 0.7200183 (5000)	total: 25.7s	remaining: 1m 17s
# 6000:	learn: 0.5563446	test: 0.7191698	best: 0.7191698 (6000)	total: 32s	remaining: 1m 14s
# 7000:	learn: 0.5554648	test: 0.7185406	best: 0.7185406 (7000)	total: 37s	remaining: 1m 8s
# 8000:	learn: 0.5547682	test: 0.7180891	best: 0.7180890 (7998)	total: 42.5s	remaining: 1m 3s
# 9000:	learn: 0.5541232	test: 0.7176133	best: 0.7176133 (9000)	total: 47.6s	remaining: 58.2s
# 10000:	learn: 0.5535904	test: 0.7172420	best: 0.7172420 (10000)	total: 53s	remaining: 53s
# 11000:	learn: 0.5531456	test: 0.7169591	best: 0.7169589 (10999)	total: 58.1s	remaining: 47.5s
# 12000:	learn: 0.5527407	test: 0.7167237	best: 0.7167237 (12000)	total: 1m 4s	remaining: 42.8s
# 13000:	learn: 0.5523806	test: 0.7165310	best: 0.7165310 (13000)	total: 1m 9s	remaining: 37.3s
# 14000:	learn: 0.5520430	test: 0.7163895	best: 0.7163895 (14000)	total: 1m 14s	remaining: 32s
# 15000:	learn: 0.5517304	test: 0.7162575	best: 0.7162575 (15000)	total: 1m 19s	remaining: 26.6s
# 16000:	learn: 0.5514441	test: 0.7161565	best: 0.7161560 (15999)	total: 1m 25s	remaining: 21.3s
# 17000:	learn: 0.5511826	test: 0.7160644	best: 0.7160640 (16987)	total: 1m 30s	remaining: 15.9s
# 18000:	learn: 0.5509286	test: 0.7159582	best: 0.7159553 (17993)	total: 1m 36s	remaining: 10.7s
# 19000:	learn: 0.
# 11000:	learn: 0.5531488	test: 0.7189491	best: 0.7189491 (11000)	total: 58.8s	remaining: 48.1s
# 12000:	learn: 0.5527420	test: 0.7187134	best: 0.7187134 (12000)	total: 1m 4s	remaining: 42.8s
# 13000:	learn: 0.5523845	test: 0.7185579	best: 0.7185579 (12991)	total: 1m 9s	remaining: 37.3s
# 14000:	learn: 0.5520491	test: 0.7184166	best: 0.7184156 (13996)	total: 1m 14s	remaining: 32s
# 15000:	learn: 0.5517423	test: 0.7182908	best: 0.7182908 (15000)	total: 1m 19s	remaining: 26.6s
# 16000:	learn: 0.5514613	test: 0.7181944	best: 0.7181919 (15965)	total: 1m 25s	remaining: 21.3s
# 17000:	learn: 0.5511988	test: 0.7180871	best: 0.7180871 (17000)	total: 1m 31s	remaining: 16.1s
# 18000:	learn: 0.5509492	test: 0.7180041	best: 0.7180029 (17806)	total: 1m 36s	remaining: 10.7s
# bestTest = 0.7180028655
# bestIteration = 17806
# Shrink model to first 17807 iterations.
# 0:	learn: 0.5924217	test: 0.7475888	best: 0.7475888 (0)	total: 5.88ms	remaining: 1m 57s
# 1000:	learn: 0.5692422	test: 0.7299173	best: 0.7299173 (1000)	total: 4.97s	remaining: 1m 34s
# 2000:	learn: 0.5642438	test: 0.7262626	best: 0.7262626 (2000)	total: 10.3s	remaining: 1m 32s
# 3000:	learn: 0.5611579	test: 0.7241246	best: 0.7241245 (2999)	total: 15.4s	remaining: 1m 27s
# 4000:	learn: 0.5590625	test: 0.7226612	best: 0.7226612 (4000)	total: 20.7s	remaining: 1m 22s
# 5000:	learn: 0.5575967	test: 0.7216738	best: 0.7216738 (5000)	total: 26.7s	remaining: 1m 20s
# 6000:	learn: 0.5564908	test: 0.7209420	best: 0.7209420 (6000)	total: 32.2s	remaining: 1m 15s
# 7000:	learn: 0.5556114	test: 0.7204373	best: 0.7204373 (7000)	total: 37.3s	remaining: 1m 9s
# 8000:	learn: 0.5548976	test: 0.7200310	best: 0.7200310 (8000)	total: 42.8s	remaining: 1m 4s
# 9000:	learn: 0.5542862	test: 0.7196739	best: 0.7196739 (9000)	total: 47.9s	remaining: 58.5s
# 10000:	learn: 0.5537395	test: 0.7193999	best: 0.7193989 (9991)	total: 53.3s	remaining: 53.3s
# 11000:	learn: 0.5532895	test: 0.7191637	best: 0.7191637 (11000)	total: 59.3s	remaining: 48.5s
# 12000:	learn: 0.5528783	test: 0.7189568	best: 0.7189568 (12000)	total: 1m 4s	remaining: 43.2s
# 13000:	learn: 0.5525190	test: 0.7187631	best: 0.7187631 (13000)	total: 1m 9s	remaining: 37.6s
# 14000:	learn: 0.5521845	test: 0.7186515	best: 0.7186514 (13994)	total: 1m 15s	remaining: 32.2s
# 15000:	learn: 0.5518824	test: 0.7185120	best: 0.7185113 (14983)	total: 1m 20s	remaining: 26.7s
# 16000:	learn: 0.5515925	test: 0.7184007	best: 0.7183995 (15945)	total: 1m 25s	remaining: 21.4s
# 17000:	learn: 0.5513350	test: 0.7183125	best: 0.7183114 (16976)	total: 1m 31s	remaining: 16.1s
# 18000:	learn: 0.5510877	test: 0.7182442	best: 0.7182420 (17979)	total: 1m 36s	remaining: 10.7s
# 19000:	learn: 0.5508542	test: 0.7181902	best: 0.7181902 (19000)	total: 1m 41s	remaining: 5.35s
# 19999:	learn: 0.5506298	test: 0.7181334	best: 0.7181312 (19896)	total: 1m 47s	remaining: 0us
# bestTest = 0.7181312209
# bestIteration = 19896
# Shrink model to first 19897 iterations.
# fold 4 - ctb rmse: 0.717951, elapsed time: 317.03sec
#
# ===== fold 5 =====
# 0:	learn: 0.5921767	test: 0.7508297	best: 0.7508297 (0)	total: 5.87ms	remaining: 1m 57s
# 1000:	learn: 0.5688869	test: 0.7339908	best: 0.7339908 (1000)	total: 4.89s	remaining: 1m 32s
# 2000:	learn: 0.5638597	test: 0.7305457	best: 0.7305457 (2000)	total: 10.2s	remaining: 1m 31s
# 3000:	learn: 0.5607926	test: 0.7284200	best: 0.7284200 (3000)	total: 15.8s	remaining: 1m 29s
# 4000:	learn: 0.5587380	test: 0.7269426	best: 0.7269426 (4000)	total: 21.3s	remaining: 1m 25s
# 5000:	learn: 0.5572449	test: 0.7258859	best: 0.7258859 (5000)	total: 26.4s	remaining: 1m 19s
# 6000:	learn: 0.5561726	test: 0.7251188	best: 0.7251188 (6000)	total: 31.7s	remaining: 1m 13s
# 7000:	learn: 0.5552946	test: 0.7245510	best: 0.7245502 (6999)	total: 36.7s	remaining: 1m 8s
# 8000:	learn: 0.5545643	test: 0.7240872	best: 0.7240872 (8000)	total: 42s	remaining: 1m 3s
# 9000:	learn: 0.5539603	test: 0.7237371	best: 0.7237368 (8999)	total: 47.9s	remaining: 58.6s
# 10000:	learn: 0.5534115	test: 0.7234046	best: 0.7234028 (9994)	total: 53.5s	remaining: 53.5s
# 11000:	learn: 0.5529451	test: 0.7231530	best: 0.7231530 (11000)	total: 58.5s	remaining: 47.9s
# 12000:	learn: 0.5525320	test: 0.7229209	best: 0.7229208 (11998)	total: 1m 3s	remaining: 42.6s
# 13000:	learn: 0.5521656	test: 0.7227542	best: 0.7227529 (12998)	total: 1m 8s	remaining: 37.1s
# 14000:	learn: 0.5518288	test: 0.7226191	best: 0.7226173 (13993)	total: 1m 14s	remaining: 31.8s
# 15000:	learn: 0.5515180	test: 0.7225080	best: 0.7225064 (14969)	total: 1m 20s	remaining: 26.7s
# 16000:	learn: 0.5512349	test: 0.7224060	best: 0.7224060 (16000)	total: 1m 25s	remaining: 21.4s
# 17000:	learn: 0.5509633	test: 0.7223240	best: 0.7223229 (16998)	total: 1m 30s	remaining: 16s
# 18000:	learn: 0.5507066	test: 0.7222327	best: 0.7222326 (17998)	total: 1m 35s	remaining: 10.7s
# 19000:	learn: 0.5504688	test: 0.7221530	best: 0.7221529 (18959)	total: 1m 41s	remaining: 5.31s
# 19999:	learn: 0.5502488	test: 0.7220986	best: 0.7220953 (19965)	total: 1m 46s	remaining: 0us
# bestTest = 0.7220953329
# bestIteration = 19965
# Shrink model to first 19966 iterations.
# 0:	learn: 0.5921771	test: 0.7508312	best: 0.7508312 (0)	total: 6.09ms	remaining: 2m 1s
# 1000:	learn: 0.5688794	test: 0.7339922	best: 0.7339922 (1000)	total: 5.85s	remaining: 1m 51s
# 2000:	learn: 0.5637971	test: 0.7303388	best: 0.7303388 (2000)	total: 11.3s	remaining: 1m 41s
# 3000:	learn: 0.5606899	test: 0.7282071	best: 0.7282071 (3000)	total: 16.4s	remaining: 1m 33s
# 4000:	learn: 0.5585843	test: 0.7267933	best: 0.7267933 (4000)	total: 21.8s	remaining: 1m 27s
# 5000:	learn: 0.5570773	test: 0.7256988	best: 0.7256988 (5000)	total: 26.9s	remaining: 1m 20s
# 6000:	learn: 0.5559447	test: 0.7248775	best: 0.7248775 (6000)	total: 32.4s	remaining: 1m 15s
# 7000:	learn: 0.5551189	test: 0.7243162	best: 0.7243161 (6999)	total: 38s	remaining: 1m 10s
# 8000:	learn: 0.5543920	test: 0.7238186	best: 0.7238186 (8000)	total: 43.5s	remaining: 1m 5s
# 9000:	learn: 0.5537744	test: 0.7234297	best: 0.7234297 (9000)	total: 48.5s	remaining: 59.3s
# 10000:	learn: 0.5532476	test: 0.7231163	best: 0.7231163 (10000)	total: 53.9s	remaining: 53.9s
# 11000:	learn: 0.5527728	test: 0.7228612	best: 0.7228612 (11000)	total: 58.8s	remaining: 48.1s
# 12000:	learn: 0.5523661	test: 0.7226354	best: 0.7226328 (11990)	total: 1m 4s	remaining: 42.8s
# 13000:	learn: 0.5519898	test: 0.7224749	best: 0.7224743 (12998)	total: 1m 9s	remaining: 37.7s
# 14000:	learn: 0.5516593	test: 0.7223307	best: 0.7223302 (13997)	total: 1m 15s	remaining: 32.4s
# 15000:	learn: 0.5513468	test: 0.7221997	best: 0.7221995 (14999)	total: 1m 20s	remaining: 26.8s
# 16000:	learn: 0.5510597	test: 0.7220911	best: 0.7220909 (15979)	total: 1m 25s	remaining: 21.5s
# 17000:	learn: 0.5507837	test: 0.7219974	best: 0.7219959 (16995)	total: 1m 31s	remaining: 16.1s
# bestTest = 0.7219863483
# bestIteration = 17147
# Shrink model to first 17148 iterations.
# 0:	learn: 0.5921770	test: 0.7508300	best: 0.7508300 (0)	total: 5.9ms	remaining: 1m 57s
# 1000:	learn: 0.5688245	test: 0.7339459	best: 0.7339459 (1000)	total: 5.54s	remaining: 1m 45s
# 2000:	learn: 0.5638102	test: 0.7304577	best: 0.7304577 (2000)	total: 11.2s	remaining: 1m 40s
# 3000:	learn: 0.5607149	test: 0.7283036	best: 0.7283036 (3000)	total: 16.3s	remaining: 1m 32s
# 4000:	learn: 0.5586356	test: 0.7267994	best: 0.7267994 (4000)	total: 21.6s	remaining: 1m 26s
# 5000:	learn: 0.5571691	test: 0.7257671	best: 0.7257671 (5000)	total: 26.7s	remaining: 1m 20s
# 6000:	learn: 0.5560685	test: 0.7249732	best: 0.7249732 (6000)	total: 32.1s	remaining: 1m 14s
# 7000:	learn: 0.5552143	test: 0.7244056	best: 0.7244056 (7000)	total: 37.8s	remaining: 1m 10s
# 8000:	learn: 0.5545206	test: 0.7239251	best: 0.7239247 (7998)	total: 43.3s	remaining: 1m 4s
# 9000:	learn: 0.5539257	test: 0.7235578	best: 0.7235576 (8998)	total: 48.4s	remaining: 59.1s
# 10000:	learn: 0.5533896	test: 0.7232712	best: 0.7232711 (9999)	total: 53.8s	remaining: 53.8s
# 11000:	learn: 0.5529202	test: 0.7230523	best: 0.7230496 (10974)	total: 58.8s	remaining: 48.1s
# 12000:	learn: 0.5525119	test: 0.7228798	best: 0.7228798 (12000)	total: 1m 4s	remaining: 42.7s
# 13000:	learn: 0.5521263	test: 0.7226999	best: 0.7226993 (12975)	total: 1m 9s	remaining: 37.7s
# 14000:	learn: 0.5517798	test: 0.7225648	best: 0.7225641 (13987)	total: 1m 15s	remaining: 32.4s
# 15000:	learn: 0.5514647	test: 0.7224276	best: 0.7224273 (14997)	total: 1m 20s	remaining: 26.9s
# 16000:	learn: 0.5511789	test: 0.7223198	best: 0.7223196 (15997)	total: 1m 25s	remaining: 21.4s
# 17000:	learn: 0.5509103	test: 0.7222355	best: 0.7222350 (16999)	total: 1m 31s	remaining: 16.1s
# 18000:	learn: 0.5506531	test: 0.7221780	best: 0.7221740 (17900)	total: 1m 36s	remaining: 10.7s
# 19000:	learn: 0.5504174	test: 0.7221260	best: 0.7221260 (19000)	total: 1m 42s	remaining: 5.37s
# 19999:	learn: 0.5501884	test: 0.7220646	best: 0.7220640 (19994)	total: 1m 47s	remaining: 0us
# bestTest = 0.7220639767
# bestIteration = 19994
# Shrink model to first 19995 iterations.
# fold 5 - ctb rmse: 0.721934, elapsed time: 316.44sec
#
# ===== fold 6 =====
# 0:	learn: 0.5923330	test: 0.7485171	best: 0.7485171 (0)	total: 6.1ms	remaining: 2m 1s
# 1000:	learn: 0.5690304	test: 0.7310463	best: 0.7310463 (1000)	total: 5.08s	remaining: 1m 36s
# 2000:	learn: 0.5640642	test: 0.7273843	best: 0.7273843 (2000)	total: 10.5s	remaining: 1m 34s
# 3000:	learn: 0.5609956	test: 0.7251890	best: 0.7251890 (3000)	total: 15.7s	remaining: 1m 28s
# 4000:	learn: 0.5589224	test: 0.7236091	best: 0.7236091 (4000)	total: 21.1s	remaining: 1m 24s
# 5000:	learn: 0.5574310	test: 0.7225107	best: 0.7225107 (5000)	total: 27s	remaining: 1m 21s
# 6000:	learn: 0.5563327	test: 0.7217214	best: 0.7217203 (5995)	total: 32.6s	remaining: 1m 15s
# 7000:	learn: 0.5554540	test: 0.7211260	best: 0.7211260 (7000)	total: 37.7s	remaining: 1m 9s
# 8000:	learn: 0.5547260	test: 0.7206506	best: 0.7206502 (7998)	total: 43.1s	remaining: 1m 4s
# 9000:	learn: 0.5541063	test: 0.7202621	best: 0.7202621 (9000)	total: 48.1s	remaining: 58.8s
# 10000:	learn: 0.5535679	test: 0.7199630	best: 0.7199630 (10000)	total: 53.5s	remaining: 53.5s
# 11000:	learn: 0.5530863	test: 0.7196863	best: 0.7196863 (11000)	total: 59.4s	remaining: 48.6s
# 12000:	learn: 0.5526794	test: 0.7194835	best: 0.7194824 (11996)	total: 1m 4s	remaining: 43.3s
# 13000:	learn: 0.5522990	test: 0.7192992	best: 0.7192989 (12999)	total: 1m 9s	remaining: 37.6s
# 14000:	learn: 0.5519585	test: 0.7191082	best: 0.7191082 (14000)	total: 1m 15s	remaining: 32.3s
# 15000:	learn: 0.5516489	test: 0.7189919	best: 0.7189907 (14966)	total: 1m 20s	remaining: 26.8s
# 16000:	learn: 0.5513595	test: 0.7188676	best: 0.7188668 (15989)	total: 1m 25s	remaining: 21.4s
# 17000:	learn: 0.5510919	test: 0.7187872	best: 0.7187872 (17000)	total: 1m 31s	remaining: 16.2s
# 18000:	learn: 0.5508410	test: 0.7186968	best: 0.7186967 (17998)	total: 1m 37s	remaining: 10.8s
# 19000:	learn: 0.5506047	test: 0.7186205	best: 0.7186205 (19000)	total: 1m 42s	remaining: 5.38s
# bestTest = 0.7186196406
# bestIteration = 19015
# Shrink model to first 19016 iterations.
# 0:	learn: 0.5923327	test: 0.7485180	best: 0.7485180 (0)	total: 6.18ms	remaining: 2m 3s
# 1000:	learn: 0.5690585	test: 0.7310985	best: 0.7310985 (1000)	total: 5.23s	remaining: 1m 39s
# 2000:	learn: 0.5641295	test: 0.7274230	best: 0.7274230 (2000)	total: 10.2s	remaining: 1m 31s
# 3000:	learn: 0.5610402	test: 0.7251959	best: 0.7251959 (3000)	total: 16.3s	remaining: 1m 32s
# 4000:	learn: 0.5589662	test: 0.7236678	best: 0.7236672 (3999)	total: 21.5s	remaining: 1m 26s
# 5000:	learn: 0.5574283	test: 0.7224875	best: 0.7224875 (5000)	total: 27s	remaining: 1m 21s
# 6000:	learn: 0.5563273	test: 0.7217316	best: 0.7217315 (5998)	total: 32.1s	remaining: 1m 14s
# 7000:	learn: 0.5554491	test: 0.7211659	best: 0.7211659 (7000)	total: 37.4s	remaining: 1m 9s
# 8000:	learn: 0.5547176	test: 0.7207146	best: 0.7207137 (7992)	total: 42.5s	remaining: 1m 3s
# 9000:	learn: 0.5540859	test: 0.7203435	best: 0.7203423 (8996)	total: 48.5s	remaining: 59.2s
# 10000:	learn: 0.5535668	test: 0.7200379	best: 0.7200379 (10000)	total: 53.5s	remaining: 53.5s
# 11000:	learn: 0.5530926	test: 0.7197840	best: 0.7197836 (10997)	total: 59.2s	remaining: 48.4s
# 12000:	learn: 0.5527025	test: 0.7195957	best: 0.7195957 (12000)	total: 1m 4s	remaining: 42.8s
# 13000:	learn: 0.5523457	test: 0.7194608	best: 0.7194596 (12997)	total: 1m 9s	remaining: 37.5s
# 14000:	learn: 0.5520127	test: 0.7193101	best: 0.7193098 (13971)	total: 1m 14s	remaining: 32s
# 15000:	learn: 0.5517172	test: 0.7192044	best: 0.7192037 (14992)	total: 1m 20s	remaining: 26.8s
# 16000:	learn: 0.5514325	test: 0.7190940	best: 0.7190940 (16000)	total: 1m 25s	remaining: 21.4s
# 17000:	learn: 0.5511623	test: 0.7189917	best: 0.7189902 (16993)	total: 1m 31s	remaining: 16.1s
# 18000:	learn: 0.5509176	test: 0.7189008	best: 0.7189006 (17999)	total: 1m 36s	remaining: 10.7s
# 19000:	learn: 0.5506852	test: 0.7188015	best: 0.7188015 (18995)	total: 1m 41s	remaining: 5.34s
# 19999:	learn: 0.5504695	test: 0.7187400	best: 0.7187348 (19827)	total: 1m 46s	remaining: 0us
# bestTest = 0.7187348474
# bestIteration = 19827
# Shrink model to first 19828 iterations.
# 0:	learn: 0.5923328	test: 0.7485172	best: 0.7485172 (0)	total: 6.29ms	remaining: 2m 5s
# 1000:	learn: 0.5691316	test: 0.7310970	best: 0.7310970 (1000)	total: 6.1s	remaining: 1m 55s
# 2000:	learn: 0.5640861	test: 0.7272819	best: 0.7272819 (2000)	total: 11.2s	remaining: 1m 40s
# 3000:	learn: 0.5609963	test: 0.7250491	best: 0.7250491 (3000)	total: 16.8s	remaining: 1m 35s
# 4000:	learn: 0.5588801	test: 0.7234769	best: 0.7234769 (4000)	total: 21.9s	remaining: 1m 27s
# 5000:	learn: 0.5573437	test: 0.7223024	best: 0.7223016 (4997)	total: 27.3s	remaining: 1m 21s
# 6000:	learn: 0.5562169	test: 0.7214882	best: 0.7214882 (6000)	total: 32.4s	remaining: 1m 15s
# 7000:	learn: 0.5553399	test: 0.7208795	best: 0.7208795 (7000)	total: 38.4s	remaining: 1m 11s
# 8000:	learn: 0.5546274	test: 0.7204214	best: 0.7204198 (7989)	total: 43.5s	remaining: 1m 5s
# 9000:	learn: 0.5540079	test: 0.7200547	best: 0.7200539 (8999)	total: 49s	remaining: 59.9s
# 10000:	learn: 0.5534912	test: 0.7197551	best: 0.7197548 (9999)	total: 54s	remaining: 54s
# 11000:	learn: 0.5530410	test: 0.7195422	best: 0.7195422 (11000)	total: 59.4s	remaining: 48.6s
# 12000:	learn: 0.5526258	test: 0.7193314	best: 0.7193314 (12000)	total: 1m 4s	remaining: 43s
# 13000:	learn: 0.5522485	test: 0.7191438	best: 0.7191433 (12997)	total: 1m 10s	remaining: 38s
# 14000:	learn: 0.5519192	test: 0.7190195	best: 0.7190191 (13981)	total: 1m 15s	remaining: 32.4s
# 15000:	learn: 0.5516104	test: 0.7188876	best: 0.7188870 (14998)	total: 1m 21s	remaining: 27.1s
# 16000:	learn: 0.5513278	test: 0.7187639	best: 0.7187639 (15998)	total: 1m 26s	remaining: 21.6s
# 17000:	learn: 0.5510612	test: 0.7186734	best: 0.7186733 (16996)	total: 1m 31s	remaining: 16.2s
# 18000:	learn: 0.5508134	test: 0.7185877	best: 0.7185877 (18000)	total: 1m 36s	remaining: 10.7s
# 19000:	learn: 0.5505762	test: 0.7184903	best: 0.7184887 (18989)	total: 1m 42s	remaining: 5.4s
# 19999:	learn: 0.5503586	test: 0.7184444	best: 0.7184444 (19984)	total: 1m 47s	remaining: 0us
# bestTest = 0.7184443938
# bestIteration = 19984
# Shrink model to first 19985 iterations.
# fold 6 - ctb rmse: 0.718498, elapsed time: 327.63sec
#
# ===== fold 7 =====
# 0:	learn: 0.5927329	test: 0.7437875	best: 0.7437875 (0)	total: 12.1ms	remaining: 4m 2s
# 1000:	learn: 0.5693894	test: 0.7262359	best: 0.7262359 (1000)	total: 5.05s	remaining: 1m 35s
# 2000:	learn: 0.5645031	test: 0.7228335	best: 0.7228329 (1998)	total: 10.1s	remaining: 1m 31s
# 3000:	learn: 0.5613601	test: 0.7205763	best: 0.7205763 (3000)	total: 15.5s	remaining: 1m 27s
# 4000:	learn: 0.5592908	test: 0.7190780	best: 0.7190765 (3998)	total: 20.6s	remaining: 1m 22s
# 5000:	learn: 0.5578260	test: 0.7180894	best: 0.7180883 (4997)	total: 26.8s	remaining: 1m 20s
# 6000:	learn: 0.5567050	test: 0.7173818	best: 0.7173799 (5995)	total: 31.8s	remaining: 1m 14s
# 7000:	learn: 0.5558399	test: 0.7168861	best: 0.7168861 (7000)	total: 37.6s	remaining: 1m 9s
# 8000:	learn: 0.5551225	test: 0.7165053	best: 0.7165053 (8000)	total: 42.7s	remaining: 1m 4s
# 14000:	learn: 0.5523150	test: 0.7149065	best: 0.7149065 (14000)	total: 1m 14s	remaining: 31.9s
# 15000:	learn: 0.5520100	test: 0.7147939	best: 0.7147938 (14996)	total: 1m 20s	remaining: 26.8s
# 16000:	learn: 0.5517238	test: 0.7147228	best: 0.7147207 (15978)	total: 1m 25s	remaining: 21.3s
# 17000:	learn: 0.5514579	test: 0.7146436	best: 0.7146415 (16953)	total: 1m 30s	remaining: 16s
# 18000:	learn: 0.5512013	test: 0.7145691	best: 0.7145684 (17982)	total: 1m 35s	remaining: 10.7s
# 19000:	learn: 0.5509633	test: 0.7145158	best: 0.7145137 (18931)	total: 1m 41s	remaining: 5.33s
# 19999:	learn: 0.5507438	test: 0.7144754	best: 0.7144730 (19910)	total: 1m 46s	remaining: 0us
# bestTest = 0.7144730284
# bestIteration = 19910
# Shrink model to first 19911 iterations.
# 0:	learn: 0.5927328	test: 0.7437862	best: 0.7437862 (0)	total: 6.25ms	remaining: 2m 4s
# 1000:	learn: 0.5692175	test: 0.7261298	best: 0.7261298 (1000)	total: 5.8s	remaining: 1m 50s
# 2000:	learn: 0.5645309	test: 0.7228195	best: 0.7228195 (2000)	total: 11.2s	remaining: 1m 40s
# 3000:	learn: 0.5613090	test: 0.7204115	best: 0.7204115 (3000)	total: 16.3s	remaining: 1m 32s
# 4000:	learn: 0.5592609	test: 0.7188711	best: 0.7188711 (4000)	total: 21.5s	remaining: 1m 26s
# 5000:	learn: 0.5577977	test: 0.7178605	best: 0.7178588 (4998)	total: 26.7s	remaining: 1m 20s
# 6000:	learn: 0.5566933	test: 0.7171634	best: 0.7171634 (6000)	total: 31.8s	remaining: 1m 14s
# 7000:	learn: 0.5558396	test: 0.7166651	best: 0.7166646 (6999)	total: 38s	remaining: 1m 10s
# 8000:	learn: 0.5551226	test: 0.7162984	best: 0.7162984 (8000)	total: 43.3s	remaining: 1m 4s
# 9000:	learn: 0.5544982	test: 0.7159921	best: 0.7159921 (9000)	total: 48.4s	remaining: 59.2s
# 10000:	learn: 0.5539431	test: 0.7157703	best: 0.7157703 (10000)	total: 53.5s	remaining: 53.5s
# 11000:	learn: 0.5534677	test: 0.7155304	best: 0.7155304 (11000)	total: 59s	remaining: 48.2s
# 12000:	learn: 0.5530482	test: 0.7153357	best: 0.7153357 (12000)	total: 1m 4s	remaining: 42.7s
# 13000:	learn: 0.5526788	test: 0.7151930	best: 0.7151930 (13000)	total: 1m 10s	remaining: 37.7s
# 14000:	learn: 0.5523350	test: 0.7150369	best: 0.7150365 (13995)	total: 1m 15s	remaining: 32.2s
# 15000:	learn: 0.5520368	test: 0.7149138	best: 0.7149121 (14995)	total: 1m 20s	remaining: 26.9s
# 16000:	learn: 0.5517510	test: 0.7148006	best: 0.7147998 (15994)	total: 1m 25s	remaining: 21.4s
# 17000:	learn: 0.5514929	test: 0.7147201	best: 0.7147190 (16926)	total: 1m 31s	remaining: 16.1s
# 18000:	learn: 0.5512405	test: 0.7146352	best: 0.7146344 (17994)	total: 1m 36s	remaining: 10.7s
# 19000:	learn: 0.5510032	test: 0.7145532	best: 0.7145520 (18926)	total: 1m 42s	remaining: 5.38s
# 19999:	learn: 0.5507724	test: 0.7144930	best: 0.7144925 (19976)	total: 1m 47s	remaining: 0us
# bestTest = 0.7144924508
# bestIteration = 19976
# Shrink model to first 19977 iterations.
# fold 7 - ctb rmse: 0.714489, elapsed time: 331.20sec
#
# ===== fold 8 =====
# 0:	learn: 0.5927298	test: 0.7465311	best: 0.7465311 (0)	total: 6.16ms	remaining: 2m 3s
# 1000:	learn: 0.5694851	test: 0.7284051	best: 0.7284051 (1000)	total: 5.04s	remaining: 1m 35s
# 2000:	learn: 0.5644467	test: 0.7246476	best: 0.7246476 (2000)	total: 10.4s	remaining: 1m 33s
# 3000:	learn: 0.5614267	test: 0.7224646	best: 0.7224646 (3000)	total: 15.5s	remaining: 1m 27s
# 4000:	learn: 0.5593279	test: 0.7209718	best: 0.7209715 (3999)	total: 20.9s	remaining: 1m 23s
# 5000:	learn: 0.5578304	test: 0.7199092	best: 0.7199092 (5000)	total: 26.5s	remaining: 1m 19s
# 6000:	learn: 0.5567189	test: 0.7191416	best: 0.7191405 (5991)	total: 31.8s	remaining: 1m 14s
# 7000:	learn: 0.5558725	test: 0.7185894	best: 0.7185891 (6999)	total: 37s	remaining: 1m 8s
# 8000:	learn: 0.5551308	test: 0.7181510	best: 0.7181510 (8000)	total: 42.4s	remaining: 1m 3s
# 9000:	learn: 0.5545399	test: 0.7178273	best: 0.7178273 (9000)	total: 47.5s	remaining: 58s
# 10000:	learn: 0.5540183	test: 0.7175385	best: 0.7175382 (9999)	total: 52.7s	remaining: 52.7s
# 11000:	learn: 0.5535320	test: 0.7172911	best: 0.7172909 (10990)	total: 58.6s	remaining: 47.9s
# 12000:	learn: 0.5531214	test: 0.7170873	best: 0.7170873 (12000)	total: 1m 3s	remaining: 42.6s
# 13000:	learn: 0.5527444	test: 0.7168798	best: 0.7168772 (12978)	total: 1m 9s	remaining: 37.3s
# 14000:	learn: 0.5524043	test: 0.7167514	best: 0.7167514 (14000)	total: 1m 14s	remaining: 31.9s
# 15000:	learn: 0.5520965	test: 0.7166212	best: 0.7166201 (14952)	total: 1m 19s	remaining: 26.5s
# 16000:	learn: 0.5518117	test: 0.7165185	best: 0.7165184 (15995)	total: 1m 24s	remaining: 21.2s
# 17000:	learn: 0.5515510	test: 0.7164495	best: 0.7164490 (16941)	total: 1m 30s	remaining: 16s
# 18000:	learn: 0.5513091	test: 0.7163777	best: 0.7163774 (17999)	total: 1m 35s	remaining: 10.6s
# bestTest = 0.7163632121
# bestIteration = 18163
# Shrink model to first 18164 iterations.
# 0:	learn: 0.5927295	test: 0.7465298	best: 0.7465298 (0)	total: 5.94ms	remaining: 1m 58s
# 1000:	learn: 0.5695291	test: 0.7284231	best: 0.7284231 (1000)	total: 4.82s	remaining: 1m 31s
# 2000:	learn: 0.5645716	test: 0.7246859	best: 0.7246859 (2000)	total: 10.2s	remaining: 1m 31s
# 3000:	learn: 0.5614147	test: 0.7224268	best: 0.7224268 (3000)	total: 15.4s	remaining: 1m 27s
# 4000:	learn: 0.5593502	test: 0.7209850	best: 0.7209850 (4000)	total: 21.1s	remaining: 1m 24s
# 5000:	learn: 0.5578503	test: 0.7199034	best: 0.7199034 (5000)	total: 26.4s	remaining: 1m 19s
# 6000:	learn: 0.5567422	test: 0.7191522	best: 0.7191522 (6000)	total: 31.9s	remaining: 1m 14s
# 7000:	learn: 0.5558607	test: 0.7185916	best: 0.7185914 (6999)	total: 37s	remaining: 1m 8s
# 8000:	learn: 0.5551212	test: 0.7181611	best: 0.7181611 (8000)	total: 42.3s	remaining: 1m 3s
# 9000:	learn: 0.5545018	test: 0.7177775	best: 0.7177775 (9000)	total: 47.4s	remaining: 57.9s
# 10000:	learn: 0.5539648	test: 0.7174838	best: 0.7174834 (9997)	total: 52.7s	remaining: 52.7s
# 11000:	learn: 0.5534969	test: 0.7172413	best: 0.7172413 (11000)	total: 58.6s	remaining: 48s
# 12000:	learn: 0.5530791	test: 0.7170313	best: 0.7170313 (12000)	total: 1m 4s	remaining: 42.8s
# 13000:	learn: 0.5527042	test: 0.7168554	best: 0.7168547 (12998)	total: 1m 9s	remaining: 37.3s
# 14000:	learn: 0.5523702	test: 0.7167266	best: 0.7167263 (13999)	total: 1m 14s	remaining: 32s
# 15000:	learn: 0.5520683	test: 0.7166228	best: 0.7166228 (15000)	total: 1m 19s	remaining: 26.6s
# 16000:	learn: 0.5517874	test: 0.7165461	best: 0.7165455 (15976)	total: 1m 25s	remaining: 21.3s
# 17000:	learn: 0.5515116	test: 0.7164943	best: 0.7164943 (17000)	total: 1m 30s	remaining: 16s
# 18000:	learn: 0.5512660	test: 0.7164321	best: 0.7164299 (17978)	total: 1m 36s	remaining: 10.7s
# 19000:	learn: 0.5510328	test: 0.7163718	best: 0.7163678 (18950)	total: 1m 41s	remaining: 5.32s
# 19999:	learn: 0.5508086	test: 0.7163284	best: 0.7163271 (19971)	total: 1m 46s	remaining: 0us
# bestTest = 0.7163270877
# bestIteration = 19971
# Shrink model to first 19972 iterations.
# 0:	learn: 0.5927301	test: 0.7465315	best: 0.7465315 (0)	total: 5.94ms	remaining: 1m 58s
# 1000:	learn: 0.5694713	test: 0.7283017	best: 0.7283017 (1000)	total: 4.99s	remaining: 1m 34s
# 2000:	learn: 0.5645408	test: 0.7246601	best: 0.7246601 (2000)	total: 10.8s	remaining: 1m 37s
# 3000:	learn: 0.5614975	test: 0.7224952	best: 0.7224952 (3000)	total: 16s	remaining: 1m 30s
# 4000:	learn: 0.5593276	test: 0.7209411	best: 0.7209411 (4000)	total: 21.6s	remaining: 1m 26s
# 5000:	learn: 0.5578480	test: 0.7198937	best: 0.7198937 (4999)	total: 26.6s	remaining: 1m 19s
# 6000:	learn: 0.5567045	test: 0.7191227	best: 0.7191227 (6000)	total: 31.9s	remaining: 1m 14s
# 7000:	learn: 0.5558446	test: 0.7186164	best: 0.7186164 (7000)	total: 37s	remaining: 1m 8s
# 8000:	learn: 0.5551280	test: 0.7181875	best: 0.7181865 (7996)	total: 42.8s	remaining: 1m 4s
# 9000:	learn: 0.5545209	test: 0.7178313	best: 0.7178312 (8999)	total: 48.4s	remaining: 59.1s
# 10000:	learn: 0.5539793	test: 0.7175571	best: 0.7175568 (9995)	total: 53.9s	remaining: 53.9s
# 11000:	learn: 0.5535053	test: 0.7173028	best: 0.7173028 (11000)	total: 58.9s	remaining: 48.2s
# 12000:	learn: 0.5530757	test: 0.7170956	best: 0.7170956 (12000)	total: 1m 4s	remaining: 42.9s
# 13000:	learn: 0.5527056	test: 0.7169005	best: 0.7169004 (12999)	total: 1m 9s	remaining: 37.4s
# 14000:	learn: 0.5523670	test: 0.7167511	best: 0.7167504 (13994)	total: 1m 15s	remaining: 32.1s
# 15000:	learn: 0.5520531	test: 0.7166521	best: 0.7166510 (14996)	total: 1m 20s	remaining: 26.9s
# 16000:	learn: 0.5517811	test: 0.7165666	best: 0.7165664 (15999)	total: 1m 26s	remaining: 21.5s
# 17000:	learn: 0.5515157	test: 0.7164802	best: 0.7164802 (17000)	total: 1m 31s	remaining: 16.1s
# 18000:	learn: 0.5512663	test: 0.7163990	best: 0.7163958 (17917)	total: 1m 36s	remaining: 10.7s
# bestTest = 0.7163548389
# bestIteration = 18688
# Shrink model to first 18689 iterations.
# fold 8 - ctb rmse: 0.716247, elapsed time: 315.12sec
#
# ===== fold 9 =====
# 0:	learn: 0.5921780	test: 0.7492516	best: 0.7492516 (0)	total: 6.12ms	remaining: 2m 2s
# 1000:	learn: 0.5688260	test: 0.7311577	best: 0.7311577 (1000)	total: 5.84s	remaining: 1m 50s
# 2000:	learn: 0.5639584	test: 0.7276147	best: 0.7276147 (2000)	total: 10.9s	remaining: 1m 38s
# 3000:	learn: 0.5608407	test: 0.7251728	best: 0.7251728 (3000)	total: 16.4s	remaining: 1m 32s
# 4000:	learn: 0.5587896	test: 0.7235889	best: 0.7235888 (3999)	total: 21.5s	remaining: 1m 25s
# 5000:	learn: 0.5572674	test: 0.7224547	best: 0.7224547 (5000)	total: 26.9s	remaining: 1m 20s
# 6000:	learn: 0.5561769	test: 0.7217192	best: 0.7217192 (6000)	total: 32s	remaining: 1m 14s
# 7000:	learn: 0.5553235	test: 0.7211507	best: 0.7211507 (7000)	total: 37.8s	remaining: 1m 10s
# 8000:	learn: 0.5545984	test: 0.7206522	best: 0.7206522 (8000)	total: 43.1s	remaining: 1m 4s
# 9000:	learn: 0.5539818	test: 0.7203254	best: 0.7203252 (8999)	total: 48.7s	remaining: 59.5s
# 10000:	learn: 0.5534648	test: 0.7200351	best: 0.7200347 (9999)	total: 53.8s	remaining: 53.8s
# 11000:	learn: 0.5530086	test: 0.7197761	best: 0.7197755 (10999)	total: 59.1s	remaining: 48.3s
# 12000:	learn: 0.5525827	test: 0.7195613	best: 0.7195613 (12000)	total: 1m 4s	remaining: 42.8s
# 13000:	learn: 0.5522232	test: 0.7194079	best: 0.7194074 (12999)	total: 1m 9s	remaining: 37.5s
# 14000:	learn: 0.5518828	test: 0.7192700	best: 0.7192685 (13972)	total: 1m 15s	remaining: 32.4s
# 15000:	learn: 0.5515769	test: 0.7191549	best: 0.7191544 (14998)	total: 1m 20s	remaining: 27s
# 16000:	learn: 0.5512996	test: 0.7190650	best: 0.7190641 (15997)	total: 1m 25s	remaining: 21.5s
# bestTest = 0.719039587
# bestIteration = 16285
# Shrink model to first 16286 iterations.
# 0:	learn: 0.5921777	test: 0.7492519	best: 0.7492519 (0)	total: 6.19ms	remaining: 2m 3s
# 1000:	learn: 0.5689440	test: 0.7312181	best: 0.7312181 (1000)	total: 5.04s	remaining: 1m 35s
# 2000:	learn: 0.5639391	test: 0.7275217	best: 0.7275208 (1999)	total: 10.5s	remaining: 1m 34s
# 3000:	learn: 0.5608365	test: 0.7251488	best: 0.7251488 (3000)	total: 16.1s	remaining: 1m 31s
# 4000:	learn: 0.5586919	test: 0.7234511	best: 0.7234511 (4000)	total: 21.6s	remaining: 1m 26s
# 5000:	learn: 0.5572253	test: 0.7223578	best: 0.7223578 (5000)	total: 26.7s	remaining: 1m 20s
# 6000:	learn: 0.5561349	test: 0.7216226	best: 0.7216226 (6000)	total: 32.1s	remaining: 1m 14s
# 7000:	learn: 0.5552515	test: 0.7209824	best: 0.7209824 (7000)	total: 37.2s	remaining: 1m 8s
# 8000:	learn: 0.5545305	test: 0.7205302	best: 0.7205302 (8000)	total: 42.5s	remaining: 1m 3s
# 9000:	learn: 0.5539024	test: 0.7201229	best: 0.7201216 (8994)	total: 48.2s	remaining: 58.9s
# 10000:	learn: 0.5533720	test: 0.7198171	best: 0.7198171 (10000)	total: 53.8s	remaining: 53.8s
# 11000:	learn: 0.5529167	test: 0.7195756	best: 0.7195745 (10997)	total: 58.9s	remaining: 48.2s
# 12000:	learn: 0.5524958	test: 0.7193837	best: 0.7193834 (11999)	total: 1m 4s	remaining: 42.9s
# 13000:	learn: 0.5521303	test: 0.7192237	best: 0.7192203 (12926)	total: 1m 9s	remaining: 37.4s
# 14000:	learn: 0.5517827	test: 0.7191081	best: 0.7191054 (13926)	total: 1m 14s	remaining: 32s
# 15000:	learn: 0.5514662	test: 0.7189779	best: 0.7189770 (14985)	total: 1m 20s	remaining: 26.8s
# 16000:	learn: 0.5511825	test: 0.7188842	best: 0.7188835 (15983)	total: 1m 26s	remaining: 21.5s
# 17000:	learn: 0.5509124	test: 0.7187979	best: 0.7187972 (16999)	total: 1m 31s	remaining: 16.1s
# 18000:	learn: 0.5506616	test: 0.7187101	best: 0.7187098 (17997)	total: 1m 36s	remaining: 10.7s
# 19000:	learn: 0.5504285	test: 0.7186416	best: 0.7186393 (18986)	total: 1m 41s	remaining: 5.35s
# 19999:	learn: 0.5502107	test: 0.7185908	best: 0.7185905 (19998)	total: 1m 46s	remaining: 0us
# bestTest = 0.7185904858
# bestIteration = 19998
# Shrink model to first 19999 iterations.
# 0:	learn: 0.5921778	test: 0.7492513	best: 0.7492513 (0)	total: 5.89ms	remaining: 1m 57s
# 1000:	learn: 0.5688046	test: 0.7310646	best: 0.7310646 (1000)	total: 5.75s	remaining: 1m 49s
# 2000:	learn: 0.5639541	test: 0.7275228	best: 0.7275228 (2000)	total: 11.3s	remaining: 1m 41s
# 3000:	learn: 0.5608103	test: 0.7250778	best: 0.7250778 (3000)	total: 16.4s	remaining: 1m 32s
# 4000:	learn: 0.5587575	test: 0.7234925	best: 0.7234925 (4000)	total: 21.9s	remaining: 1m 27s
# 5000:	learn: 0.5572740	test: 0.7224007	best: 0.7224007 (5000)	total: 27s	remaining: 1m 20s
# 6000:	learn: 0.5561367	test: 0.7216450	best: 0.7216450 (6000)	total: 32.4s	remaining: 1m 15s
# 7000:	learn: 0.5552762	test: 0.7211016	best: 0.7211015 (6998)	total: 38s	remaining: 1m 10s
# 8000:	learn: 0.5545448	test: 0.7206473	best: 0.7206473 (8000)	total: 43.6s	remaining: 1m 5s
# 9000:	learn: 0.5539224	test: 0.7202837	best: 0.7202830 (8997)	total: 48.7s	remaining: 59.5s
# 10000:	learn: 0.5533790	test: 0.7199807	best: 0.7199806 (9999)	total: 54.1s	remaining: 54.1s
# 11000:	learn: 0.5529129	test: 0.7197180	best: 0.7197176 (10997)	total: 59.1s	remaining: 48.4s
# 12000:	learn: 0.5524989	test: 0.7195371	best: 0.7195369 (11998)	total: 1m 4s	remaining: 42.9s
# 13000:	learn: 0.5521198	test: 0.7193515	best: 0.7193515 (12997)	total: 1m 9s	remaining: 37.7s
# 14000:	learn: 0.5517848	test: 0.7192255	best: 0.7192255 (14000)	total: 1m 15s	remaining: 32.4s
# 15000:	learn: 0.5514728	test: 0.7191484	best: 0.7191472 (14997)	total: 1m 20s	remaining: 26.9s
# 16000:	learn: 0.5511839	test: 0.7190310	best: 0.7190310 (16000)	total: 1m 26s	remaining: 21.5s
# 17000:	learn: 0.5509302	test: 0.7189411	best: 0.7189411 (17000)	total: 1m 31s	remaining: 16.1s
# 18000:	learn: 0.5506815	test: 0.7188757	best: 0.7188741 (17987)	total: 1m 36s	remaining: 10.7s
# 19000:	learn: 0.5504464	test: 0.7188285	best: 0.7188265 (18984)	total: 1m 42s	remaining: 5.38s
# 19999:	learn: 0.5502250	test: 0.7187548	best: 0.7187534 (19993)	total: 1m 48s	remaining: 0us
# bestTest = 0.7187533811
# bestIteration = 19993
# Shrink model to first 19994 iterations.
# fold 9 - ctb rmse: 0.718672, elapsed time: 312.95sec
#
# oof ctb_rmse = 0.7160883278918171

# %% [markdown]
# # OOF predictions

# %%
plt.plot(train[target], train[target])
plt.scatter(train[target], ctb_oof)

# %% [markdown]
# # Features importances

# %%
order = list(ctb_importances.groupby('feature').mean().sort_values('importance', ascending=False).index)

fig = plt.figure(figsize=(16, 16), tight_layout=True)
sns.barplot(x="importance", y="feature", data=ctb_importances.groupby('feature').mean().reset_index(), order=order)
plt.title("CatB feature importances")
# Out:
# Text(0.5, 1.0, 'CatB feature importances')

# %% [markdown]
# # Submission

# %%
submission[target] = ctb_pred
submission.to_csv("submission.csv", index=False)

submission
# Out:
#             id    target
# 0            0  8.089647
# 1            5  8.381990
# 2           15  8.367081
# 3           16  8.500210
# 4           17  8.189332
# ...        ...       ...
# 199995  499987  8.066390
# 199996  499990  8.502864
# 199997  499991  8.503873
# 199998  499994  8.171828
# 199999  499995  7.978063
#
# [200000 rows x 2 columns]
