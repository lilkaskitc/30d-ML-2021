# %%
# Familiar imports
import numpy as np
import pandas as pd
import random
import os
import time
import pickle
from pathlib import Path

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

from scipy.optimize import minimize

#import lightgbm as lgb
import xgboost as xgb
#import catboost as ctb

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # Parameters

# %%
target = 'target'

DEBUG = False

if DEBUG:
    N_ESTIMATORS = 1
    N_SPLITS = 2
    SEED = 17
    CVSEED = 17
    EARLY_STOPPING_ROUNDS = 1
    VERBOSE = 100
    #N_ITERS = 2
else:
    N_SPLITS = 10
    N_ESTIMATORS = 20000
    EARLY_STOPPING_ROUNDS = 200
    VERBOSE = 1000
    SEED = 17
    CVSEED = 17
    #N_ITERS = 10

# %%
def set_seed(seed=17):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
set_seed(SEED)

# %% [markdown]
# # Load data

# %%
# Load the training data
train = pd.read_csv("../input/30-days-of-ml/train.csv")
test = pd.read_csv("../input/30-days-of-ml/test.csv")
submission = pd.read_csv("../input/30-days-of-ml/sample_submission.csv")

# Preview the data
train.head()
# Out:
#    id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont5     cont6  \
# 0   1    B    B    B    C    B    B    A    E    C  ...  0.400361  0.160266
# 1   2    B    B    A    A    B    D    A    F    A  ...  0.533087  0.558922
# 2   3    A    A    A    C    B    D    A    D    A  ...  0.650609  0.375348
# 3   4    B    B    A    C    B    D    A    E    C  ...  0.668980  0.239061
# 4   6    A    A    A    C    B    D    A    E    A  ...  0.686964  0.420667
#
#       cont7     cont8     cont9    cont10    cont11    cont12    cont13  \
# 0  0.310921  0.389470  0.267559  0.237281  0.377873  0.322401  0.869850
# 1  0.516294  0.594928  0.341439  0.906013  0.921701  0.261975  0.465083
# 2  0.902567  0.555205  0.843531  0.748809  0.620126  0.541474  0.763846
# 3  0.732948  0.679618  0.574844  0.346010  0.714610  0.540150  0.280682
# 4  0.648182  0.684501  0.956692  1.000773  0.776742  0.625849  0.250823
#
#      target
# 0  8.113634
# 1  8.481233
# 2  8.364351
# 3  8.049253
# 4  7.972260
#
# [5 rows x 26 columns]

# %%
# Low MI scores
for pp in ["cat2","cat3","cat4","cat6"]:
    train.pop(pp)
    test.pop(pp)
train.head()
# Out:
#    id cat0 cat1 cat5 cat7 cat8 cat9     cont0     cont1     cont2  ...  \
# 0   1    B    B    B    E    C    N  0.201470 -0.014822  0.669699  ...
# 1   2    B    B    D    F    A    O  0.743068  0.367411  1.021605  ...
# 2   3    A    A    D    D    A    F  0.742708  0.310383 -0.012673  ...
# 3   4    B    B    D    E    C    K  0.429551  0.620998  0.577942  ...
# 4   6    A    A    D    E    A    N  1.058291  0.367492 -0.052389  ...
#
#       cont5     cont6     cont7     cont8     cont9    cont10    cont11  \
# 0  0.400361  0.160266  0.310921  0.389470  0.267559  0.237281  0.377873
# 1  0.533087  0.558922  0.516294  0.594928  0.341439  0.906013  0.921701
# 2  0.650609  0.375348  0.902567  0.555205  0.843531  0.748809  0.620126
# 3  0.668980  0.239061  0.732948  0.679618  0.574844  0.346010  0.714610
# 4  0.686964  0.420667  0.648182  0.684501  0.956692  1.000773  0.776742
#
#      cont12    cont13    target
# 0  0.322401  0.869850  8.113634
# 1  0.261975  0.465083  8.481233
# 2  0.541474  0.763846  8.364351
# 3  0.540150  0.280682  8.049253
# 4  0.625849  0.250823  7.972260
#
# [5 rows x 22 columns]

# %%
# Separate target from features
y = train['target']
features = train.drop(['id','target'], axis=1)

# Preview features
features.head()
# Out:
#   cat0 cat1 cat5 cat7 cat8 cat9     cont0     cont1     cont2     cont3  \
# 0    B    B    B    E    C    N  0.201470 -0.014822  0.669699  0.136278
# 1    B    B    D    F    A    O  0.743068  0.367411  1.021605  0.365798
# 2    A    A    D    D    A    F  0.742708  0.310383 -0.012673  0.576957
# 3    B    B    D    E    C    K  0.429551  0.620998  0.577942  0.280610
# 4    A    A    D    E    A    N  1.058291  0.367492 -0.052389  0.232407
#
#       cont4     cont5     cont6     cont7     cont8     cont9    cont10  \
# 0  0.610706  0.400361  0.160266  0.310921  0.389470  0.267559  0.237281
# 1  0.276853  0.533087  0.558922  0.516294  0.594928  0.341439  0.906013
# 2  0.285074  0.650609  0.375348  0.902567  0.555205  0.843531  0.748809
# 3  0.284667  0.668980  0.239061  0.732948  0.679618  0.574844  0.346010
# 4  0.287595  0.686964  0.420667  0.648182  0.684501  0.956692  1.000773
#
#      cont11    cont12    cont13
# 0  0.377873  0.322401  0.869850
# 1  0.921701  0.261975  0.465083
# 2  0.620126  0.541474  0.763846
# 3  0.714610  0.540150  0.280682
# 4  0.776742  0.625849  0.250823

# %% [markdown]
# # Preprocessing

# %%
# List of categorical columns
object_cols = [col for col in features.columns if 'cat' in col]

# ordinal-encode categorical columns
X = features.copy()
X_test = test.drop(['id'], axis=1).copy()
ordinal_encoder = OrdinalEncoder()
X[object_cols] = ordinal_encoder.fit_transform(features[object_cols])
X_test[object_cols] = ordinal_encoder.transform(test[object_cols])

# Preview the ordinal-encoded features
X.head()
# Out:
#    cat0  cat1  cat5  cat7  cat8  cat9     cont0     cont1     cont2     cont3  \
# 0   1.0   1.0   1.0   4.0   2.0  13.0  0.201470 -0.014822  0.669699  0.136278
# 1   1.0   1.0   3.0   5.0   0.0  14.0  0.743068  0.367411  1.021605  0.365798
# 2   0.0   0.0   3.0   3.0   0.0   5.0  0.742708  0.310383 -0.012673  0.576957
# 3   1.0   1.0   3.0   4.0   2.0  10.0  0.429551  0.620998  0.577942  0.280610
# 4   0.0   0.0   3.0   4.0   0.0  13.0  1.058291  0.367492 -0.052389  0.232407
#
#       cont4     cont5     cont6     cont7     cont8     cont9    cont10  \
# 0  0.610706  0.400361  0.160266  0.310921  0.389470  0.267559  0.237281
# 1  0.276853  0.533087  0.558922  0.516294  0.594928  0.341439  0.906013
# 2  0.285074  0.650609  0.375348  0.902567  0.555205  0.843531  0.748809
# 3  0.284667  0.668980  0.239061  0.732948  0.679618  0.574844  0.346010
# 4  0.287595  0.686964  0.420667  0.648182  0.684501  0.956692  1.000773
#
#      cont11    cont12    cont13
# 0  0.377873  0.322401  0.869850
# 1  0.921701  0.261975  0.465083
# 2  0.620126  0.541474  0.763846
# 3  0.714610  0.540150  0.280682
# 4  0.776742  0.625849  0.250823

# %%
'''
# List of categorical columns
object_cols = [col for col in features.columns if 'cat' in col]

# one-hot-encode categorical columns
X = features.copy()
X_test = test.drop(['id'], axis=1).copy()

oh_encoder = OneHotEncoder(sparse=False, handle_unknown="ignore")
X_ohe = oh_encoder.fit_transform(features[object_cols])
X_test_ohe = oh_encoder.transform(test[object_cols])

X_ohe = pd.DataFrame(X_ohe, columns=[f"ohe_{i}" for i in range(X_ohe.shape[1])])
X_test_ohe = pd.DataFrame(X_test_ohe, columns=[f"ohe_{i}" for i in range(X_test_ohe.shape[1])])

X = pd.concat([X, X_ohe], axis=1)
X_test = pd.concat([X_test, X_test_ohe], axis=1)
X = X.drop(object_cols, axis=1)
X_test = X_test.drop(object_cols, axis=1)
    
# Preview the one-hot-encoded features
X.head()
'''
# Out:
# '\n# List of categorical columns\nobject_cols = [col for col in features.columns if \'cat\' in col]\n\n# one-hot-encode categorical columns\nX = features.copy()\nX_test = test.drop([\'id\'], axis=1).copy()\n\noh_encoder = OneHotEncoder(sparse=False, handle_unknown="ignore")\nX_ohe = oh_encoder.fit_transform(features[object_cols])\nX_test_ohe = oh_encoder.transform(test[object_cols])\n\nX_ohe = pd.DataFrame(X_ohe, columns=[f"ohe_{i}" for i in range(X_ohe.shape[1])])\nX_test_ohe = pd.DataFrame(X_test_ohe, columns=[f"ohe_{i}" for i in range(X_test_ohe.shape[1])])\n\nX = pd.concat([X, X_ohe], axis=1)\nX_test = pd.concat([X_test, X_test_ohe], axis=1)\nX = X.drop(object_cols, axis=1)\nX_test = X_test.drop(object_cols, axis=1)\n    \n# Preview the one-hot-encoded features\nX.head()\n'

# %%
scale_features = [col for col in features.columns if 'cont' in col]

ss = StandardScaler()
X[scale_features] = ss.fit_transform(features[scale_features])
X_test[scale_features] = ss.transform(test[scale_features])

# %%
# Swap noise

# Random
def apply_noise_rn(df, p=.75):
    should_not_swap = np.random.binomial(1, p, df.shape)
    corrupted_df = df.where(should_not_swap == 1, np.random.permutation(df))
    return corrupted_df

# Row-wise
def apply_noise_row(df, p=.75):
    should_not_swap = np.zeros(df.shape)
    for i in range(df.shape[0]):
        for j in np.random.choice(df.shape[1],int(p*df.shape[1]),replace=False):
            should_not_swap[i,j]=1 
    corrupted_df = df.where(should_not_swap == 1, np.random.permutation(df))
    return corrupted_df

# %% [markdown]
# # XGB

# %%
xgb_params = {
        'objective': 'reg:squarederror',
        'n_estimators':N_ESTIMATORS,
    'importance_type': 'total_gain',
            'tree_method': 'hist',
    
    'learning_rate': 0.036955320792692224,
     'subsample': 0.7635473153188327,
     'colsample_bytree': 0.1354938997791723,
     'max_depth': 3,
     'lambda': 22.821468405823435,
     'alpha': 9.002866837758342,
     'min_child_weight': 402.0811006541652
}

# %%
xgb_oof = np.zeros(train.shape[0])
xgb_pred = np.zeros(test.shape[0])
xgb_importances = pd.DataFrame()

kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=CVSEED)
seed_list=[SEED, SEED+1, SEED+2]

for fold, (trn_idx, val_idx) in enumerate(kf.split(X=X, y=y)):
    print(f"===== fold {fold} =====")
       
    X_train, y_train = X.iloc[trn_idx], y.iloc[trn_idx]
    #X_train = apply_noise_row(X_train)
    
    X_valid, y_valid = X.iloc[val_idx], y.iloc[val_idx]
    X_test = X_test
    
    # XGB
    start = time.time()
    
    for inseed in seed_list:
        xgb_params['seed'] = inseed
    
        pre_model = xgb.XGBRegressor(**xgb_params)
        pre_model.fit(
            X_train, 
            y_train,
            eval_set=[(X_valid, y_valid)],
            eval_metric='rmse',
            early_stopping_rounds=EARLY_STOPPING_ROUNDS,
            verbose=VERBOSE
            
        )

        xgb_params2 = xgb_params.copy()
        xgb_params2['lambda'] *= 0.9
        xgb_params2['alpha'] *= 0.9
        xgb_params2['learning_rate'] *= 0.1
        model = xgb.XGBRegressor(**xgb_params2)
        model.fit(
                X_train, y_train,
                eval_set=[(X_valid, y_valid)],
                eval_metric='rmse',
                early_stopping_rounds=EARLY_STOPPING_ROUNDS,
                verbose=VERBOSE,
                xgb_model=pre_model
               
        )    

        with open(f"xgb_model{fold}.pkl", 'wb') as f:
            pickle.dump(model, f)

        fi_tmp = pd.DataFrame()
        fi_tmp['feature'] = X.columns
        fi_tmp['importance'] = model.feature_importances_
        fi_tmp['fold'] = fold
        fi_tmp['seed'] = inseed
        xgb_importances = xgb_importances.append(fi_tmp)

        xgb_oof[val_idx] += model.predict(X_valid) / len(seed_list)
        xgb_pred += model.predict(X_test) / len(seed_list)
    
    elapsed = time.time() - start
    rmse = mean_squared_error(y_valid, xgb_oof[val_idx], squared=False)
    print(f"fold {fold} - xgb rmse: {rmse:.6f}, elapsed time: {elapsed:.2f}sec\n")

xgb_pred /= N_SPLITS
print(f"oof xgb_rmse = {mean_squared_error(y, xgb_oof, squared=False)}")

np.save("xgb_oof.npy", xgb_oof)
np.save("xgb_pred.npy", xgb_pred)
# Out:
# ===== fold 0 =====
# [0]	validation_0-rmse:7.49028
# [1000]	validation_0-rmse:0.71779
# [2000]	validation_0-rmse:0.71435
# [3000]	validation_0-rmse:0.71301
# [4000]	validation_0-rmse:0.71245
# [5000]	validation_0-rmse:0.71223
# [5130]	validation_0-rmse:0.71223
# [0]	validation_0-rmse:0.71223
# [804]	validation_0-rmse:0.71221
# [0]	validation_0-rmse:7.49018
# [1000]	validation_0-rmse:0.71771
# [2000]	validation_0-rmse:0.71428
# [3000]	validation_0-rmse:0.71291
# [4000]	validation_0-rmse:0.71237
# [4547]	validation_0-rmse:0.71232
# [0]	validation_0-rmse:0.71232
# [1000]	validation_0-rmse:0.71230
# [2000]	validation_0-rmse:0.71227
# [2540]	validation_0-rmse:0.71226
# [0]	validation_0-rmse:7.49017
# [1000]	validation_0-rmse:0.71825
# [2000]	validation_0-rmse:0.71442
# [3000]	validation_0-rmse:0.71309
# [4000]	validation_0-rmse:0.71251
# [5000]	validation_0-rmse:0.71225
# [5572]	validation_0-rmse:0.71217
# [0]	validation_0-rmse:0.71218
# [276]	validation_0-rmse:0.71218
# fold 0 - xgb rmse: 0.712154, elapsed time: 410.75sec
#
# ===== fold 1 =====
# [0]	validation_0-rmse:7.49216
# [1000]	validation_0-rmse:0.72335
# [2000]	validation_0-rmse:0.71984
# [3000]	validation_0-rmse:0.71853
# [4000]	validation_0-rmse:0.71792
# [5000]	validation_0-rmse:0.71768
# [5960]	validation_0-rmse:0.71755
# [0]	validation_0-rmse:0.71754
# [199]	validation_0-rmse:0.71755
# [0]	validation_0-rmse:7.49217
# [1000]	validation_0-rmse:0.72357
# [2000]	validation_0-rmse:0.71966
# [3000]	validation_0-rmse:0.71839
# [4000]	validation_0-rmse:0.71783
# [5000]	validation_0-rmse:0.71761
# [5522]	validation_0-rmse:0.71758
# [0]	validation_0-rmse:0.71758
# [693]	validation_0-rmse:0.71757
# [0]	validation_0-rmse:7.49214
# [1000]	validation_0-rmse:0.72395
# [2000]	validation_0-rmse:0.71999
# [3000]	validation_0-rmse:0.71858
# [4000]	validation_0-rmse:0.71792
# [5000]	validation_0-rmse:0.71769
# [6000]	validation_0-rmse:0.71755
# [6189]	validation_0-rmse:0.71755
# [0]	validation_0-rmse:0.71755
# [358]	validation_0-rmse:0.71755
# fold 1 - xgb rmse: 0.717493, elapsed time: 414.38sec
#
# ===== fold 2 =====
# [0]	validation_0-rmse:7.49376
# [1000]	validation_0-rmse:0.72327
# [2000]	validation_0-rmse:0.71963
# [3000]	validation_0-rmse:0.71818
# [4000]	validation_0-rmse:0.71753
# [5000]	validation_0-rmse:0.71722
# [6000]	validation_0-rmse:0.71701
# [6837]	validation_0-rmse:0.71693
# [0]	validation_0-rmse:0.71693
# [997]	validation_0-rmse:0.71692
# [0]	validation_0-rmse:7.49379
# [1000]	validation_0-rmse:0.72327
# [2000]	validation_0-rmse:0.71953
# [3000]	validation_0-rmse:0.71805
# [4000]	validation_0-rmse:0.71749
# [5000]	validation_0-rmse:0.71718
# [6000]	validation_0-rmse:0.71701
# [6540]	validation_0-rmse:0.71698
# [0]	validation_0-rmse:0.71698
# [599]	validation_0-rmse:0.71697
# [0]	validation_0-rmse:7.49383
# [1000]	validation_0-rmse:0.72350
# [2000]	validation_0-rmse:0.71964
# [3000]	validation_0-rmse:0.71810
# [4000]	validation_0-rmse:0.71747
# [5000]	validation_0-rmse:0.71719
# [6000]	validation_0-rmse:0.71701
# [6602]	validation_0-rmse:0.71697
# [0]	validation_0-rmse:0.71697
# [200]	validation_0-rmse:0.71697
# fold 2 - xgb rmse: 0.716886, elapsed time: 475.96sec
#
# ===== fold 3 =====
# [0]	validation_0-rmse:7.48820
# [1000]	validation_0-rmse:0.71978
# [2000]	validation_0-rmse:0.71632
# [3000]	validation_0-rmse:0.71490
# [4000]	validation_0-rmse:0.71431
# [5000]	validation_0-rmse:0.71403
# [6000]	validation_0-rmse:0.71387
# [6743]	validation_0-rmse:0.71379
# [0]	validation_0-rmse:0.71379
# [985]	validation_0-rmse:0.71378
# [0]	validation_0-rmse:7.48819
# [1000]	validation_0-rmse:0.71976
# [2000]	validation_0-rmse:0.71622
# [3000]	validation_0-rmse:0.71491
# [4000]	validation_0-rmse:0.71429
# [5000]	validation_0-rmse:0.71400
# [6000]	validation_0-rmse:0.71381
# [6432]	validation_0-rmse:0.71380
# [0]	validation_0-rmse:0.71379
# [200]	validation_0-rmse:0.71379
# [0]	validation_0-rmse:7.48823
# [1000]	validation_0-rmse:0.72010
# [2000]	validation_0-rmse:0.71625
# [3000]	validation_0-rmse:0.71496
# [4000]	validation_0-rmse:0.71437
# [5000]	validation_0-rmse:0.71403
# [6000]	validation_0-rmse:0.71387
# [6297]	validation_0-rmse:0.71387
# [0]	validation_0-rmse:0.71387
# [1000]	validation_0-rmse:0.71386
# [1261]	validation_0-rmse:0.71386
# fold 3 - xgb rmse: 0.713742, elapsed time: 479.71sec
#
# ===== fold 4 =====
# [0]	validation_0-rmse:7.49333
# [1000]	validation_0-rmse:0.72003
# [2000]	validation_0-rmse:0.71658
# [3000]	validation_0-rmse:0.71546
# [4000]	validation_0-rmse:0.71494
# [5000]	validation_0-rmse:0.71470
# [6000]	validation_0-rmse:0.71457
# [6321]	validation_0-rmse:0.71456
# [0]	validation_0-rmse:0.71456
# [211]	validation_0-rmse:0.71457
# [0]	validation_0-rmse:7.49335
# [1000]	validation_0-rmse:0.72005
# [2000]	validation_0-rmse:0.71663
# [3000]	validation_0-rmse:0.71553
# [4000]	validation_0-rmse:0.71502
# [5000]	validation_0-rmse:0.71481
# [5673]	validation_0-rmse:0.71475
# [0]	validation_0-rmse:0.71475
# [447]	validation_0-rmse:0.71474
# [0]	validation_0-rmse:7.49334
# [1000]	validation_0-rmse:0.72041
# [2000]	validation_0-rmse:0.71669
# [3000]	validation_0-rmse:0.71552
# [4000]	validation_0-rmse:0.71500
# [5000]	validation_0-rmse:0.71477
# [5756]	validation_0-rmse:0.71474
# [0]	validation_0-rmse:0.71474
# [199]	validation_0-rmse:0.71474
# fold 4 - xgb rmse: 0.714614, elapsed time: 406.66sec
#
# ===== fold 5 =====
# [0]	validation_0-rmse:7.50131
# [1000]	validation_0-rmse:0.72752
# [2000]	validation_0-rmse:0.72368
# [3000]	validation_0-rmse:0.72208
# [4000]	validation_0-rmse:0.72134
# [5000]	validation_0-rmse:0.72102
# [5470]	validation_0-rmse:0.72094
# [0]	validation_0-rmse:0.72094
# [1000]	validation_0-rmse:0.72092
# [2000]	validation_0-rmse:0.72090
# [3000]	validation_0-rmse:0.72088
# [3018]	validation_0-rmse:0.72088
# [0]	validation_0-rmse:7.50132
# [1000]	validation_0-rmse:0.72744
# [2000]	validation_0-rmse:0.72365
# [3000]	validation_0-rmse:0.72202
# [4000]	validation_0-rmse:0.72130
# [5000]	validation_0-rmse:0.72098
# [6000]	validation_0-rmse:0.72079
# [6773]	validation_0-rmse:0.72070
# [0]	validation_0-rmse:0.72070
# [336]	validation_0-rmse:0.72070
# [0]	validation_0-rmse:7.50127
# [1000]	validation_0-rmse:0.72782
# [2000]	validation_0-rmse:0.72359
# [3000]	validation_0-rmse:0.72213
# [4000]	validation_0-rmse:0.72128
# [5000]	validation_0-rmse:0.72089
# [6000]	validation_0-rmse:0.72066
# [7000]	validation_0-rmse:0.72049
# [7199]	validation_0-rmse:0.72049
# [0]	validation_0-rmse:0.72049
# [1000]	validation_0-rmse:0.72048
# [1153]	validation_0-rmse:0.72048
# fold 5 - xgb rmse: 0.720611, elapsed time: 567.53sec
#
# ===== fold 6 =====
# [0]	validation_0-rmse:7.49721
# [1000]	validation_0-rmse:0.72389
# [2000]	validation_0-rmse:0.72015
# [3000]	validation_0-rmse:0.71872
# [4000]	validation_0-rmse:0.71810
# [5000]	validation_0-rmse:0.71785
# [5919]	validation_0-rmse:0.71779
# [0]	validation_0-rmse:0.71779
# [437]	validation_0-rmse:0.71779
# [0]	validation_0-rmse:7.49710
# [1000]	validation_0-rmse:0.72384
# [2000]	validation_0-rmse:0.72011
# [3000]	validation_0-rmse:0.71871
# [4000]	validation_0-rmse:0.71811
# [5000]	validation_0-rmse:0.71781
# [5635]	validation_0-rmse:0.71777
# [0]	validation_0-rmse:0.71777
# [201]	validation_0-rmse:0.71777
# [0]	validation_0-rmse:7.49709
# [1000]	validation_0-rmse:0.72427
# [2000]	validation_0-rmse:0.72019
# [3000]	validation_0-rmse:0.71878
# [4000]	validation_0-rmse:0.71813
# [5000]	validation_0-rmse:0.71786
# [6000]	validation_0-rmse:0.71774
# [6261]	validation_0-rmse:0.71773
# [0]	validation_0-rmse:0.71773
# [707]	validation_0-rmse:0.71772
# fold 6 - xgb rmse: 0.717698, elapsed time: 528.78sec
#
# ===== fold 7 =====
# [0]	validation_0-rmse:7.48793
# [1000]	validation_0-rmse:0.72988
# [2000]	validation_0-rmse:0.72633
# [3000]	validation_0-rmse:0.72495
# [4000]	validation_0-rmse:0.72438
# [5000]	validation_0-rmse:0.72412
# [6000]	validation_0-rmse:0.72401
# [6630]	validation_0-rmse:0.72398
# [0]	validation_0-rmse:0.72398
# [200]	validation_0-rmse:0.72398
# [0]	validation_0-rmse:7.48796
# [1000]	validation_0-rmse:0.72979
# [2000]	validation_0-rmse:0.72616
# [3000]	validation_0-rmse:0.72484
# [4000]	validation_0-rmse:0.72420
# [5000]	validation_0-rmse:0.72396
# [6000]	validation_0-rmse:0.72384
# [6366]	validation_0-rmse:0.72383
# [0]	validation_0-rmse:0.72383
# [850]	validation_0-rmse:0.72382
# [0]	validation_0-rmse:7.48798
# [1000]	validation_0-rmse:0.73010
# [2000]	validation_0-rmse:0.72628
# [3000]	validation_0-rmse:0.72490
# [4000]	validation_0-rmse:0.72418
# [5000]	validation_0-rmse:0.72387
# [5702]	validation_0-rmse:0.72382
# [0]	validation_0-rmse:0.72382
# [634]	validation_0-rmse:0.72382
# fold 7 - xgb rmse: 0.723799, elapsed time: 547.31sec
#
# ===== fold 8 =====
# [0]	validation_0-rmse:7.49469
# [1000]	validation_0-rmse:0.72325
# [2000]	validation_0-rmse:0.72000
# [3000]	validation_0-rmse:0.71891
# [4000]	validation_0-rmse:0.71849
# [4876]	validation_0-rmse:0.71834
# [0]	validation_0-rmse:0.71834
# [925]	validation_0-rmse:0.71833
# [0]	validation_0-rmse:7.49469
# [1000]	validation_0-rmse:0.72335
# [2000]	validation_0-rmse:0.72002
# [3000]	validation_0-rmse:0.71898
# [4000]	validation_0-rmse:0.71848
# [5000]	validation_0-rmse:0.71834
# [5619]	validation_0-rmse:0.71830
# [0]	validation_0-rmse:0.71830
# [275]	validation_0-rmse:0.71830
# [0]	validation_0-rmse:7.49464
# [1000]	validation_0-rmse:0.72361
# [2000]	validation_0-rmse:0.72003
# [3000]	validation_0-rmse:0.71890
# [4000]	validation_0-rmse:0.71842
# [5000]	validation_0-rmse:0.71824
# [5745]	validation_0-rmse:0.71816
# [0]	validation_0-rmse:0.71816
# [330]	validation_0-rmse:0.71816
# fold 8 - xgb rmse: 0.718196, elapsed time: 472.28sec
#
# ===== fold 9 =====
# [0]	validation_0-rmse:7.49308
# [1000]	validation_0-rmse:0.72634
# [2000]	validation_0-rmse:0.72257
# [3000]	validation_0-rmse:0.72101
# [4000]	validation_0-rmse:0.72033
# [5000]	validation_0-rmse:0.72008
# [5505]	validation_0-rmse:0.72001
# [0]	validation_0-rmse:0.72001
# [456]	validation_0-rmse:0.72000
# [0]	validation_0-rmse:7.49310
# [1000]	validation_0-rmse:0.72637
# [2000]	validation_0-rmse:0.72247
# [3000]	validation_0-rmse:0.72090
# [4000]	validation_0-rmse:0.72030
# [5000]	validation_0-rmse:0.72002
# [6000]	validation_0-rmse:0.71988
# [6602]	validation_0-rmse:0.71982
# [0]	validation_0-rmse:0.71982
# [270]	validation_0-rmse:0.71982
# [0]	validation_0-rmse:7.49310
# [1000]	validation_0-rmse:0.72665
# [2000]	validation_0-rmse:0.72265
# [3000]	validation_0-rmse:0.72110
# [4000]	validation_0-rmse:0.72036
# [5000]	validation_0-rmse:0.72003
# [6000]	validation_0-rmse:0.71984
# [7000]	validation_0-rmse:0.71979
# [7058]	validation_0-rmse:0.71979
# [0]	validation_0-rmse:0.71979
# [420]	validation_0-rmse:0.71979
# fold 9 - xgb rmse: 0.719795, elapsed time: 546.79sec
#
# oof xgb_rmse = 0.7175061009264644

# %% [markdown]
# # OOF predictions

# %%
plt.plot(train[target], train[target])
plt.scatter(train[target], xgb_oof)

# %% [markdown]
# # Features importances

# %%
order = list(xgb_importances.groupby('feature').mean().sort_values('importance', ascending=False).index)

fig = plt.figure(figsize=(16, 16), tight_layout=True)
sns.barplot(x="importance", y="feature", data=xgb_importances.groupby('feature').mean().reset_index(), order=order)
plt.title("XGB feature importances")
# Out:
# Text(0.5, 1.0, 'XGB feature importances')

# %% [markdown]
# # Submission

# %%
submission[target] = xgb_pred
submission.to_csv("submission.csv", index=False)

submission
# Out:
#             id    target
# 0            0  8.139851
# 1            5  8.401097
# 2           15  8.385099
# 3           16  8.518894
# 4           17  8.161964
# ...        ...       ...
# 199995  499987  8.031752
# 199996  499990  8.478596
# 199997  499991  8.503959
# 199998  499994  8.176920
# 199999  499995  7.954160
#
# [200000 rows x 2 columns]
