# %%
# Familiar imports
import numpy as np
import pandas as pd
import random
import os
import time
from pathlib import Path

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Ridge
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder


#import lightgbm as lgb
#import xgboost as xgb
#import catboost as ctb

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # Parameters

# %%
target = 'target'

DEBUG = False

if DEBUG:
    N_ESTIMATORS = 1
    N_SPLITS = 2
    SEED = 17
    CVSEED = 17
    EARLY_STOPPING_ROUNDS = 1
    VERBOSE = 100
    #N_ITERS = 2
else:
    N_SPLITS = 10
    N_ESTIMATORS = 10000
    EARLY_STOPPING_ROUNDS = 300
    VERBOSE = 1000
    SEED = 17
    CVSEED = 17
    #N_ITERS = 10

# %%
def set_seed(seed=17):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
set_seed(SEED)

# %% [markdown]
# # Load data

# %%
# Load the training data
train = pd.read_csv("../input/30-days-of-ml/train.csv")
test = pd.read_csv("../input/30-days-of-ml/test.csv")

# Preview the data
train.head()
# Out:
#    id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont5     cont6  \
# 0   1    B    B    B    C    B    B    A    E    C  ...  0.400361  0.160266
# 1   2    B    B    A    A    B    D    A    F    A  ...  0.533087  0.558922
# 2   3    A    A    A    C    B    D    A    D    A  ...  0.650609  0.375348
# 3   4    B    B    A    C    B    D    A    E    C  ...  0.668980  0.239061
# 4   6    A    A    A    C    B    D    A    E    A  ...  0.686964  0.420667
#
#       cont7     cont8     cont9    cont10    cont11    cont12    cont13  \
# 0  0.310921  0.389470  0.267559  0.237281  0.377873  0.322401  0.869850
# 1  0.516294  0.594928  0.341439  0.906013  0.921701  0.261975  0.465083
# 2  0.902567  0.555205  0.843531  0.748809  0.620126  0.541474  0.763846
# 3  0.732948  0.679618  0.574844  0.346010  0.714610  0.540150  0.280682
# 4  0.648182  0.684501  0.956692  1.000773  0.776742  0.625849  0.250823
#
#      target
# 0  8.113634
# 1  8.481233
# 2  8.364351
# 3  8.049253
# 4  7.972260
#
# [5 rows x 26 columns]

# %%
train['lgbl2_pred'] = np.load("../input/30d-lgb-lv2-pred/2lgb_oof.npy")+ np.load("../input/30d-lgb-lv2-pred/3lgb_oof.npy")+ np.load("../input/30d-lgb-lv2-pred/4lgb_oof.npy")
test['lgbl2_pred'] = np.load("../input/30d-lgb-lv2-pred/2lgb_pred.npy")+ np.load("../input/30d-lgb-lv2-pred/3lgb_pred.npy")+ np.load("../input/30d-lgb-lv2-pred/4lgb_pred.npy")

train['lgb_pred'] = np.load("../input/30d-ml-2021-stacking-lgb/lgb_oof.npy")
test['lgb_pred'] = np.load("../input/30d-ml-2021-stacking-lgb/lgb_pred.npy")

train['rr_pred'] = np.load("../input/30d-stacking-rf-pred/2rr_oof.npy")+np.load("../input/30d-stacking-rf-pred/3rr_oof.npy")+np.load("../input/30d-stacking-rf-pred/4rr_oof.npy")
test['rr_pred'] = np.load("../input/30d-stacking-rf-pred/2rr_pred.npy")+np.load("../input/30d-stacking-rf-pred/3rr_pred.npy")+np.load("../input/30d-stacking-rf-pred/4rr_pred.npy")

# %%
# Separate target from features
y = train['target']
features = train.drop(['id','target'], axis=1)

# Preview features
features.head()
# Out:
#   cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont7     cont8  \
# 0    B    B    B    C    B    B    A    E    C    N  ...  0.310921  0.389470
# 1    B    B    A    A    B    D    A    F    A    O  ...  0.516294  0.594928
# 2    A    A    A    C    B    D    A    D    A    F  ...  0.902567  0.555205
# 3    B    B    A    C    B    D    A    E    C    K  ...  0.732948  0.679618
# 4    A    A    A    C    B    D    A    E    A    N  ...  0.648182  0.684501
#
#       cont9    cont10    cont11    cont12    cont13  lgbl2_pred  lgb_pred  \
# 0  0.267559  0.237281  0.377873  0.322401  0.869850    8.436433  8.447180
# 1  0.341439  0.906013  0.921701  0.261975  0.465083    8.356099  8.379196
# 2  0.843531  0.748809  0.620126  0.541474  0.763846    8.209022  8.243932
# 3  0.574844  0.346010  0.714610  0.540150  0.280682    8.390101  8.404801
# 4  0.956692  1.000773  0.776742  0.625849  0.250823    8.207458  8.237940
#
#     rr_pred
# 0  8.445473
# 1  8.367401
# 2  8.242520
# 3  8.411158
# 4  8.236186
#
# [5 rows x 27 columns]

# %% [markdown]
# # Preprocessing

# %%
# List of categorical columns
object_cols = [col for col in features.columns if 'cat' in col]

# ordinal-encode categorical columns
X = features.copy()
X_test = test.drop(['id'], axis=1).copy()
ordinal_encoder = OrdinalEncoder()
X[object_cols] = ordinal_encoder.fit_transform(features[object_cols])
X_test[object_cols] = ordinal_encoder.transform(test[object_cols])

# Preview the ordinal-encoded features
X.head()
# Out:
#    cat0  cat1  cat2  cat3  cat4  cat5  cat6  cat7  cat8  cat9  ...     cont7  \
# 0   1.0   1.0   1.0   2.0   1.0   1.0   0.0   4.0   2.0  13.0  ...  0.310921
# 1   1.0   1.0   0.0   0.0   1.0   3.0   0.0   5.0   0.0  14.0  ...  0.516294
# 2   0.0   0.0   0.0   2.0   1.0   3.0   0.0   3.0   0.0   5.0  ...  0.902567
# 3   1.0   1.0   0.0   2.0   1.0   3.0   0.0   4.0   2.0  10.0  ...  0.732948
# 4   0.0   0.0   0.0   2.0   1.0   3.0   0.0   4.0   0.0  13.0  ...  0.648182
#
#       cont8     cont9    cont10    cont11    cont12    cont13  lgbl2_pred  \
# 0  0.389470  0.267559  0.237281  0.377873  0.322401  0.869850    8.436433
# 1  0.594928  0.341439  0.906013  0.921701  0.261975  0.465083    8.356099
# 2  0.555205  0.843531  0.748809  0.620126  0.541474  0.763846    8.209022
# 3  0.679618  0.574844  0.346010  0.714610  0.540150  0.280682    8.390101
# 4  0.684501  0.956692  1.000773  0.776742  0.625849  0.250823    8.207458
#
#    lgb_pred   rr_pred
# 0  8.447180  8.445473
# 1  8.379196  8.367401
# 2  8.243932  8.242520
# 3  8.404801  8.411158
# 4  8.237940  8.236186
#
# [5 rows x 27 columns]

# %%
'''
# List of categorical columns
object_cols = [col for col in features.columns if 'cat' in col]

# one-hot-encode categorical columns
X = features.copy()
X_test = test.drop(['id'], axis=1).copy()

oh_encoder = OneHotEncoder(sparse=False, handle_unknown="ignore")
X_ohe = oh_encoder.fit_transform(features[object_cols])
X_test_ohe = oh_encoder.transform(test[object_cols])

X_ohe = pd.DataFrame(X_ohe, columns=[f"ohe_{i}" for i in range(X_ohe.shape[1])])
X_test_ohe = pd.DataFrame(X_test_ohe, columns=[f"ohe_{i}" for i in range(X_test_ohe.shape[1])])

X = pd.concat([X, X_ohe], axis=1)
X_test = pd.concat([X_test, X_test_ohe], axis=1)
X = X.drop(object_cols, axis=1)
X_test = X_test.drop(object_cols, axis=1)
    
# Preview the one-hot-encoded features
X.head()
'''
# Out:
# '\n# List of categorical columns\nobject_cols = [col for col in features.columns if \'cat\' in col]\n\n# one-hot-encode categorical columns\nX = features.copy()\nX_test = test.drop([\'id\'], axis=1).copy()\n\noh_encoder = OneHotEncoder(sparse=False, handle_unknown="ignore")\nX_ohe = oh_encoder.fit_transform(features[object_cols])\nX_test_ohe = oh_encoder.transform(test[object_cols])\n\nX_ohe = pd.DataFrame(X_ohe, columns=[f"ohe_{i}" for i in range(X_ohe.shape[1])])\nX_test_ohe = pd.DataFrame(X_test_ohe, columns=[f"ohe_{i}" for i in range(X_test_ohe.shape[1])])\n\nX = pd.concat([X, X_ohe], axis=1)\nX_test = pd.concat([X_test, X_test_ohe], axis=1)\nX = X.drop(object_cols, axis=1)\nX_test = X_test.drop(object_cols, axis=1)\n    \n# Preview the one-hot-encoded features\nX.head()\n'

# %%
scale_features = [col for col in features.columns if 'pred' in col]

ss = StandardScaler()
X[scale_features] = ss.fit_transform(features[scale_features])
X_test[scale_features] = ss.transform(test[scale_features])

# %%
# Swap noise

# Random
def apply_noise_rn(df, p=.75):
    should_not_swap = np.random.binomial(1, p, df.shape)
    corrupted_df = df.where(should_not_swap == 1, np.random.permutation(df))
    return corrupted_df

# Row-wise
def apply_noise_row(df, p=.75):
    should_not_swap = np.zeros(df.shape)
    for i in range(df.shape[0]):
        for j in np.random.choice(df.shape[1],int(p*df.shape[1]),replace=False):
            should_not_swap[i,j]=1 
    corrupted_df = df.where(should_not_swap == 1, np.random.permutation(df))
    return corrupted_df

# %% [markdown]
# # Pseudo Label

# %%
pseudo = pd.read_csv("../input/competition-part-6-stacking/submission.csv")[target]
train_pseudo = pd.concat([X, y], axis=1)
test_pseudo = pd.concat([X_test, pseudo], axis=1)
all_pseudo = pd.concat([train_pseudo, test_pseudo]).reset_index(drop=True)

# %% [markdown]
# # Optuna

# %%
# Optuna for parameter search
# !pip install -q optuna

import optuna
import pickle
# Out:
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
# for the fixed learning rate, use the opt n iterations and tune the tree hyperparameters
def objective(trial, X=all_pseudo[scale_features], y=all_pseudo[target]):
  """
  """
  
  param_space = {
               'max_iter':N_ESTIMATORS,
      
               'alpha':trial.suggest_uniform('alpha', 0.01, 20),
              #'l1_ratio':trial.suggest_uniform('l1_ratio', 0.31197, 0.81197),
              #'selection':trial.suggest_categorical('selection',['cyclic', 'random'])
              'solver':trial.suggest_categorical('solver',['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga'])
      
                  }
            
  seed_list=[SEED, SEED+1]
  #kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=CVSEED)
  lgb_oof = np.zeros(train.shape[0])
  #lgb_pred = np.zeros(test.shape[0])
  X_tr, X_va, y_tr, y_va = train_test_split(X,y,test_size=.2,random_state=CVSEED)
  trn_idx = X_tr.index
  val_idx = X_va.index
  
  #for (trn_idx, val_idx) in enumerate(kf.split(X, y)):
  #print(f"===== fold {fold} =====")
  oof_idx = np.array([idx for idx in val_idx if idx < train.shape[0]])
  preds_idx = np.array([idx for idx in val_idx if idx >= train.shape[0]])

  X_train, y_train = all_pseudo[scale_features].iloc[trn_idx], all_pseudo[target].iloc[trn_idx]
  #X_train = apply_noise_row(X_train)

  X_valid, y_valid = all_pseudo[scale_features].iloc[oof_idx], all_pseudo[target].iloc[oof_idx]
  #X_test = all_pseudo[scale_features].iloc[preds_idx]
  
  #start = time.time()
  for inseed in seed_list:
    param_space['random_state'] = inseed

    model = Ridge(**param_space)
    model.fit(
        X_train, 
        y_train,
        
    )


    lgb_oof[oof_idx] += model.predict(X_valid) / len(seed_list)
    #lgb_pred[preds_idx-train.shape[0]] += model.predict(X_test) / len(seed_list)

  #elapsed = time.time() - start
  rmse = mean_squared_error(y_valid, lgb_oof[oof_idx], squared=False)
  #print(f"fold {fold} - lgb rmse: {rmse:.6f}, elapsed time: {elapsed:.2f}sec\n")            
  
  #print(f"oof lgb_rmse = {mean_squared_error(train[target], lgb_oof, squared=False)}")

  
  return rmse

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective,n_trials= 30)
print('Number of finished trials:', len(study.trials))
print('Best trial:', study.best_trial.params)
# Out:
# [I 2021-08-31 22:57:12,412] A new study created in memory with name: no-name-ce720aa7-405c-4781-a26b-1314f7ad647b
# [I 2021-08-31 22:57:12,829] Trial 0 finished with value: 0.7081851939575372 and parameters: {'alpha': 5.39077267022533, 'solver': 'cholesky'}. Best is trial 0 with value: 0.7081851939575372.
# [I 2021-08-31 22:57:13,341] Trial 1 finished with value: 0.7081851375489356 and parameters: {'alpha': 0.5081659583130587, 'solver': 'auto'}. Best is trial 1 with value: 0.7081851375489356.
# [I 2021-08-31 22:57:13,821] Trial 2 finished with value: 0.708185308642515 and parameters: {'alpha': 16.112548979358504, 'solver': 'cholesky'}. Best is trial 1 with value: 0.7081851375489356.
# [I 2021-08-31 22:57:14,310] Trial 3 finished with value: 0.7081889536698933 and parameters: {'alpha': 10.305429832179213, 'solver': 'sparse_cg'}. Best is trial 1 with value: 0.7081851375489356.
# [I 2021-08-31 22:57:18,830] Trial 4 finished with value: 0.70818499709101 and parameters: {'alpha': 1.1144051170707463, 'solver': 'sag'}. Best is trial 4 with value: 0.70818499709101.
# [I 2021-08-31 22:57:19,300] Trial 5 finished with value: 0.7081851483072652 and parameters: {'alpha': 1.4212027460696892, 'solver': 'cholesky'}. Best is trial 4 with value: 0.70818499709101.
# [I 2021-08-31 22:57:19,774] Trial 6 finished with value: 0.7081889910924143 and parameters: {'alpha': 0.9726991207690958, 'solver': 'sparse_cg'}. Best is trial 4 with value: 0.70818499709101.
# [I 2021-08-31 22:57:24,195] Trial 7 finished with value: 0.708185030790547 and parameters: {'alpha': 6.389487517931721, 'solver': 'sag'}. Best is trial 4 with value: 0.70818499709101.
# [I 2021-08-31 22:57:24,671] Trial 8 finished with value: 0.7081851829292196 and parameters: {'alpha': 4.417310396095133, 'solver': 'cholesky'}. Best is trial 4 with value: 0.70818499709101.
# [I 2021-08-31 22:57:25,155] Trial 9 finished with value: 0.7081889872451198 and parameters: {'alpha': 1.9288991291442394, 'solver': 'sparse_cg'}. Best is trial 4 with value: 0.70818499709101.
# [I 2021-08-31 22:57:28,584] Trial 10 finished with value: 0.7081853947099437 and parameters: {'alpha': 11.798867696251618, 'solver': 'saga'}. Best is trial 4 with value: 0.70818499709101.
# [I 2021-08-31 22:57:33,179] Trial 11 finished with value: 0.7081850377432197 and parameters: {'alpha': 6.914115183722745, 'solver': 'sag'}. Best is trial 4 with value: 0.70818499709101.
# [I 2021-08-31 22:57:37,732] Trial 12 finished with value: 0.7081850494725258 and parameters: {'alpha': 7.811822623436023, 'solver': 'sag'}. Best is trial 4 with value: 0.70818499709101.
# [I 2021-08-31 22:57:38,232] Trial 13 finished with value: 0.7081852856472697 and parameters: {'alpha': 13.869913861148529, 'solver': 'svd'}. Best is trial 4 with value: 0.70818499709101.
# [I 2021-08-31 22:57:43,022] Trial 14 finished with value: 0.7081849916605879 and parameters: {'alpha': 3.5633081107878697, 'solver': 'sag'}. Best is trial 14 with value: 0.7081849916605879.
# [I 2021-08-31 22:57:43,503] Trial 15 finished with value: 0.7081836292105594 and parameters: {'alpha': 19.894011899670495, 'solver': 'lsqr'}. Best is trial 15 with value: 0.7081836292105594.
# [I 2021-08-31 22:57:44,005] Trial 16 finished with value: 0.7081836292220417 and parameters: {'alpha': 19.93483577109642, 'solver': 'lsqr'}. Best is trial 15 with value: 0.7081836292105594.
# [I 2021-08-31 22:57:44,511] Trial 17 finished with value: 0.7081836290743739 and parameters: {'alpha': 19.409798787562963, 'solver': 'lsqr'}. Best is trial 17 with value: 0.7081836290743739.
# [I 2021-08-31 22:57:45,012] Trial 18 finished with value: 0.7081836291385525 and parameters: {'alpha': 19.637992627369492, 'solver': 'lsqr'}. Best is trial 17 with value: 0.7081836290743739.
# [I 2021-08-31 22:57:45,512] Trial 19 finished with value: 0.7081836285139202 and parameters: {'alpha': 17.416690907833743, 'solver': 'lsqr'}. Best is trial 19 with value: 0.7081836285139202.
# [I 2021-08-31 22:57:46,019] Trial 20 finished with value: 0.708183628438498 and parameters: {'alpha': 17.148423250443194, 'solver': 'lsqr'}. Best is trial 20 with value: 0.708183628438498.
# [I 2021-08-31 22:57:46,520] Trial 21 finished with value: 0.7081836284212654 and parameters: {'alpha': 17.087127165617364, 'solver': 'lsqr'}. Best is trial 21 with value: 0.7081836284212654.
# [I 2021-08-31 22:57:47,010] Trial 22 finished with value: 0.7081836283974049 and parameters: {'alpha': 17.00225554022648, 'solver': 'lsqr'}. Best is trial 22 with value: 0.7081836283974049.
# [I 2021-08-31 22:57:47,504] Trial 23 finished with value: 0.7081836280207934 and parameters: {'alpha': 15.662493461043827, 'solver': 'lsqr'}. Best is trial 23 with value: 0.7081836280207934.
# [I 2021-08-31 22:57:48,007] Trial 24 finished with value: 0.7081836276766534 and parameters: {'alpha': 14.437997521481226, 'solver': 'lsqr'}. Best is trial 24 with value: 0.7081836276766534.
# [I 2021-08-31 22:57:48,508] Trial 25 finished with value: 0.7081852872426764 and parameters: {'alpha': 14.023921007607726, 'solver': 'svd'}. Best is trial 24 with value: 0.7081836276766534.
# [I 2021-08-31 22:57:52,067] Trial 26 finished with value: 0.7081854154826208 and parameters: {'alpha': 14.59701726030664, 'solver': 'saga'}. Best is trial 24 with value: 0.7081836276766534.
# [I 2021-08-31 22:57:52,553] Trial 27 finished with value: 0.7081852688950452 and parameters: {'alpha': 12.266742638314085, 'solver': 'auto'}. Best is trial 24 with value: 0.7081836276766534.
# [I 2021-08-31 22:57:53,043] Trial 28 finished with value: 0.7081836279691872 and parameters: {'alpha': 15.478887030317654, 'solver': 'lsqr'}. Best is trial 24 with value: 0.7081836276766534.
# [I 2021-08-31 22:57:53,541] Trial 29 finished with value: 0.7081836279210676 and parameters: {'alpha': 15.307679805374535, 'solver': 'lsqr'}. Best is trial 24 with value: 0.7081836276766534.
# Number of finished trials: 30
# Best trial: {'alpha': 14.437997521481226, 'solver': 'lsqr'}

# %%
study.best_params
# Out:
# {'alpha': 2.3952668021671872, 'solver': 'lsqr'}

# %% [markdown]
# # Log
#
# ========== 3 preds ==============
# ====== Ordinal encoding =========
#
# 0.7081836236639212 {'alpha': 0.14259280578343692, 'solver': 'lsqr'}
#
# ====== One-hot encoding =========
