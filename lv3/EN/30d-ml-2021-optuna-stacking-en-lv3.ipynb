# %%
# Familiar imports
import numpy as np
import pandas as pd
import random
import os
import time
from pathlib import Path

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import ElasticNet
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder


#import lightgbm as lgb
#import xgboost as xgb
#import catboost as ctb

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # Parameters

# %%
target = 'target'

DEBUG = False

if DEBUG:
    N_ESTIMATORS = 1
    N_SPLITS = 2
    SEED = 17
    CVSEED = 17
    EARLY_STOPPING_ROUNDS = 1
    VERBOSE = 100
    #N_ITERS = 2
else:
    N_SPLITS = 10
    N_ESTIMATORS = 10000
    EARLY_STOPPING_ROUNDS = 300
    VERBOSE = 1000
    SEED = 17
    CVSEED = 17
    #N_ITERS = 10

# %%
def set_seed(seed=17):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
set_seed(SEED)

# %% [markdown]
# # Load data

# %%
# Load the training data
train = pd.read_csv("../input/30-days-of-ml/train.csv")
test = pd.read_csv("../input/30-days-of-ml/test.csv")

# Preview the data
train.head()
# Out:
#    id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont5     cont6  \
# 0   1    B    B    B    C    B    B    A    E    C  ...  0.400361  0.160266
# 1   2    B    B    A    A    B    D    A    F    A  ...  0.533087  0.558922
# 2   3    A    A    A    C    B    D    A    D    A  ...  0.650609  0.375348
# 3   4    B    B    A    C    B    D    A    E    C  ...  0.668980  0.239061
# 4   6    A    A    A    C    B    D    A    E    A  ...  0.686964  0.420667
#
#       cont7     cont8     cont9    cont10    cont11    cont12    cont13  \
# 0  0.310921  0.389470  0.267559  0.237281  0.377873  0.322401  0.869850
# 1  0.516294  0.594928  0.341439  0.906013  0.921701  0.261975  0.465083
# 2  0.902567  0.555205  0.843531  0.748809  0.620126  0.541474  0.763846
# 3  0.732948  0.679618  0.574844  0.346010  0.714610  0.540150  0.280682
# 4  0.648182  0.684501  0.956692  1.000773  0.776742  0.625849  0.250823
#
#      target
# 0  8.113634
# 1  8.481233
# 2  8.364351
# 3  8.049253
# 4  7.972260
#
# [5 rows x 26 columns]

# %%
train['lgbl2_pred'] = np.load("../input/30d-lgb-lv2-pred/2lgb_oof.npy")+ np.load("../input/30d-lgb-lv2-pred/3lgb_oof.npy")+ np.load("../input/30d-lgb-lv2-pred/4lgb_oof.npy")
test['lgbl2_pred'] = np.load("../input/30d-lgb-lv2-pred/2lgb_pred.npy")+ np.load("../input/30d-lgb-lv2-pred/3lgb_pred.npy")+ np.load("../input/30d-lgb-lv2-pred/4lgb_pred.npy")

train['lgb_pred'] = np.load("../input/30d-ml-2021-stacking-lgb/lgb_oof.npy")
test['lgb_pred'] = np.load("../input/30d-ml-2021-stacking-lgb/lgb_pred.npy")

train['rr_pred'] = np.load("../input/30d-stacking-rf-pred/2rr_oof.npy")+np.load("../input/30d-stacking-rf-pred/3rr_oof.npy")+np.load("../input/30d-stacking-rf-pred/4rr_oof.npy")
test['rr_pred'] = np.load("../input/30d-stacking-rf-pred/2rr_pred.npy")+np.load("../input/30d-stacking-rf-pred/3rr_pred.npy")+np.load("../input/30d-stacking-rf-pred/4rr_pred.npy")

# %%
# Separate target from features
y = train['target']
features = train.drop(['id','target'], axis=1)

# Preview features
features.head()
# Out:
#   cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont7     cont8  \
# 0    B    B    B    C    B    B    A    E    C    N  ...  0.310921  0.389470
# 1    B    B    A    A    B    D    A    F    A    O  ...  0.516294  0.594928
# 2    A    A    A    C    B    D    A    D    A    F  ...  0.902567  0.555205
# 3    B    B    A    C    B    D    A    E    C    K  ...  0.732948  0.679618
# 4    A    A    A    C    B    D    A    E    A    N  ...  0.648182  0.684501
#
#       cont9    cont10    cont11    cont12    cont13  lgbl2_pred  lgb_pred  \
# 0  0.267559  0.237281  0.377873  0.322401  0.869850    8.436433  8.447180
# 1  0.341439  0.906013  0.921701  0.261975  0.465083    8.356099  8.379196
# 2  0.843531  0.748809  0.620126  0.541474  0.763846    8.209022  8.243932
# 3  0.574844  0.346010  0.714610  0.540150  0.280682    8.390101  8.404801
# 4  0.956692  1.000773  0.776742  0.625849  0.250823    8.207458  8.237940
#
#     rr_pred
# 0  8.445473
# 1  8.367401
# 2  8.242520
# 3  8.411158
# 4  8.236186
#
# [5 rows x 27 columns]

# %% [markdown]
# # Preprocessing

# %%
# List of categorical columns
object_cols = [col for col in features.columns if 'cat' in col]

# ordinal-encode categorical columns
X = features.copy()
X_test = test.drop(['id'], axis=1).copy()
ordinal_encoder = OrdinalEncoder()
X[object_cols] = ordinal_encoder.fit_transform(features[object_cols])
X_test[object_cols] = ordinal_encoder.transform(test[object_cols])

# Preview the ordinal-encoded features
X.head()
# Out:
#    cat0  cat1  cat2  cat3  cat4  cat5  cat6  cat7  cat8  cat9  ...     cont7  \
# 0   1.0   1.0   1.0   2.0   1.0   1.0   0.0   4.0   2.0  13.0  ...  0.310921
# 1   1.0   1.0   0.0   0.0   1.0   3.0   0.0   5.0   0.0  14.0  ...  0.516294
# 2   0.0   0.0   0.0   2.0   1.0   3.0   0.0   3.0   0.0   5.0  ...  0.902567
# 3   1.0   1.0   0.0   2.0   1.0   3.0   0.0   4.0   2.0  10.0  ...  0.732948
# 4   0.0   0.0   0.0   2.0   1.0   3.0   0.0   4.0   0.0  13.0  ...  0.648182
#
#       cont8     cont9    cont10    cont11    cont12    cont13  lgbl2_pred  \
# 0  0.389470  0.267559  0.237281  0.377873  0.322401  0.869850    8.436433
# 1  0.594928  0.341439  0.906013  0.921701  0.261975  0.465083    8.356099
# 2  0.555205  0.843531  0.748809  0.620126  0.541474  0.763846    8.209022
# 3  0.679618  0.574844  0.346010  0.714610  0.540150  0.280682    8.390101
# 4  0.684501  0.956692  1.000773  0.776742  0.625849  0.250823    8.207458
#
#    lgb_pred   rr_pred
# 0  8.447180  8.445473
# 1  8.379196  8.367401
# 2  8.243932  8.242520
# 3  8.404801  8.411158
# 4  8.237940  8.236186
#
# [5 rows x 27 columns]

# %%
'''
# List of categorical columns
object_cols = [col for col in features.columns if 'cat' in col]

# one-hot-encode categorical columns
X = features.copy()
X_test = test.drop(['id'], axis=1).copy()

oh_encoder = OneHotEncoder(sparse=False, handle_unknown="ignore")
X_ohe = oh_encoder.fit_transform(features[object_cols])
X_test_ohe = oh_encoder.transform(test[object_cols])

X_ohe = pd.DataFrame(X_ohe, columns=[f"ohe_{i}" for i in range(X_ohe.shape[1])])
X_test_ohe = pd.DataFrame(X_test_ohe, columns=[f"ohe_{i}" for i in range(X_test_ohe.shape[1])])

X = pd.concat([X, X_ohe], axis=1)
X_test = pd.concat([X_test, X_test_ohe], axis=1)
X = X.drop(object_cols, axis=1)
X_test = X_test.drop(object_cols, axis=1)
    
# Preview the one-hot-encoded features
X.head()
'''
# Out:
# '\n# List of categorical columns\nobject_cols = [col for col in features.columns if \'cat\' in col]\n\n# one-hot-encode categorical columns\nX = features.copy()\nX_test = test.drop([\'id\'], axis=1).copy()\n\noh_encoder = OneHotEncoder(sparse=False, handle_unknown="ignore")\nX_ohe = oh_encoder.fit_transform(features[object_cols])\nX_test_ohe = oh_encoder.transform(test[object_cols])\n\nX_ohe = pd.DataFrame(X_ohe, columns=[f"ohe_{i}" for i in range(X_ohe.shape[1])])\nX_test_ohe = pd.DataFrame(X_test_ohe, columns=[f"ohe_{i}" for i in range(X_test_ohe.shape[1])])\n\nX = pd.concat([X, X_ohe], axis=1)\nX_test = pd.concat([X_test, X_test_ohe], axis=1)\nX = X.drop(object_cols, axis=1)\nX_test = X_test.drop(object_cols, axis=1)\n    \n# Preview the one-hot-encoded features\nX.head()\n'

# %%
scale_features = [col for col in features.columns if 'pred' in col]

ss = StandardScaler()
X[scale_features] = ss.fit_transform(features[scale_features])
X_test[scale_features] = ss.transform(test[scale_features])

# %%
# Swap noise

# Random
def apply_noise_rn(df, p=.75):
    should_not_swap = np.random.binomial(1, p, df.shape)
    corrupted_df = df.where(should_not_swap == 1, np.random.permutation(df))
    return corrupted_df

# Row-wise
def apply_noise_row(df, p=.75):
    should_not_swap = np.zeros(df.shape)
    for i in range(df.shape[0]):
        for j in np.random.choice(df.shape[1],int(p*df.shape[1]),replace=False):
            should_not_swap[i,j]=1 
    corrupted_df = df.where(should_not_swap == 1, np.random.permutation(df))
    return corrupted_df

# %% [markdown]
# # Pseudo Label

# %%
pseudo = pd.read_csv("../input/competition-part-6-stacking/submission.csv")[target]
train_pseudo = pd.concat([X, y], axis=1)
test_pseudo = pd.concat([X_test, pseudo], axis=1)
all_pseudo = pd.concat([train_pseudo, test_pseudo]).reset_index(drop=True)

# %% [markdown]
# # Optuna

# %%
# Optuna for parameter search
# !pip install -q optuna

import optuna
import pickle
# Out:
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
# for the fixed learning rate, use the opt n iterations and tune the tree hyperparameters
def objective(trial, X=all_pseudo[scale_features], y=all_pseudo[target]):
  """
  """
  
  param_space = {
               'max_iter':N_ESTIMATORS,
      
               'alpha':trial.suggest_uniform('alpha', 0.001, 20),
              'l1_ratio':trial.suggest_uniform('l1_ratio', 0,0.5),
              'selection':trial.suggest_categorical('selection',['cyclic', 'random'])
      
                  }
            
  seed_list=[SEED, SEED+1]
  #kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=CVSEED)
  lgb_oof = np.zeros(train.shape[0])
  #lgb_pred = np.zeros(test.shape[0])
  X_tr, X_va, y_tr, y_va = train_test_split(X,y,test_size=.2,random_state=CVSEED)
  trn_idx = X_tr.index
  val_idx = X_va.index
  
  #for (trn_idx, val_idx) in enumerate(kf.split(X, y)):
  #print(f"===== fold {fold} =====")
  oof_idx = np.array([idx for idx in val_idx if idx < train.shape[0]])
  preds_idx = np.array([idx for idx in val_idx if idx >= train.shape[0]])

  X_train, y_train = all_pseudo[scale_features].iloc[trn_idx], all_pseudo[target].iloc[trn_idx]
  #X_train = apply_noise_row(X_train)

  X_valid, y_valid = all_pseudo[scale_features].iloc[oof_idx], all_pseudo[target].iloc[oof_idx]
  #X_test = all_pseudo[scale_features].iloc[preds_idx]
  
  #start = time.time()
  for inseed in seed_list:
    param_space['random_state'] = inseed

    model = ElasticNet(**param_space)
    model.fit(
        X_train, 
        y_train,
        
    )


    lgb_oof[oof_idx] += model.predict(X_valid) / len(seed_list)
    #lgb_pred[preds_idx-train.shape[0]] += model.predict(X_test) / len(seed_list)

  #elapsed = time.time() - start
  rmse = mean_squared_error(y_valid, lgb_oof[oof_idx], squared=False)
  #print(f"fold {fold} - lgb rmse: {rmse:.6f}, elapsed time: {elapsed:.2f}sec\n")            
  
  #print(f"oof lgb_rmse = {mean_squared_error(train[target], lgb_oof, squared=False)}")

  
  return rmse

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective,n_trials= 30)
print('Number of finished trials:', len(study.trials))
print('Best trial:', study.best_trial.params)
# Out:
# [I 2021-08-31 22:58:44,674] A new study created in memory with name: no-name-209cf5af-2d24-4722-8050-d0635a0114b0
# [I 2021-08-31 22:58:45,125] Trial 0 finished with value: 0.7399637633374914 and parameters: {'alpha': 14.176048683281172, 'l1_ratio': 0.4001678565968364, 'selection': 'cyclic'}. Best is trial 0 with value: 0.7399637633374914.
# [I 2021-08-31 22:58:45,623] Trial 1 finished with value: 0.7399637633374914 and parameters: {'alpha': 2.4829080731505693, 'l1_ratio': 0.45542622853243, 'selection': 'cyclic'}. Best is trial 0 with value: 0.7399637633374914.
# [I 2021-08-31 22:58:46,164] Trial 2 finished with value: 0.7330559099441855 and parameters: {'alpha': 11.535172775315006, 'l1_ratio': 0.007941937159887169, 'selection': 'cyclic'}. Best is trial 2 with value: 0.7330559099441855.
# [I 2021-08-31 22:58:46,663] Trial 3 finished with value: 0.7399637633374914 and parameters: {'alpha': 11.659733510017055, 'l1_ratio': 0.4648352603434547, 'selection': 'cyclic'}. Best is trial 2 with value: 0.7330559099441855.
# [I 2021-08-31 22:58:47,169] Trial 4 finished with value: 0.7399637633374914 and parameters: {'alpha': 19.158930615740008, 'l1_ratio': 0.1268876910041099, 'selection': 'cyclic'}. Best is trial 2 with value: 0.7330559099441855.
# [I 2021-08-31 22:58:47,772] Trial 5 finished with value: 0.7399637633374914 and parameters: {'alpha': 8.96042303867633, 'l1_ratio': 0.2516366890515068, 'selection': 'random'}. Best is trial 2 with value: 0.7330559099441855.
# [I 2021-08-31 22:58:48,265] Trial 6 finished with value: 0.7399637633374914 and parameters: {'alpha': 4.665194940861379, 'l1_ratio': 0.12222444603921256, 'selection': 'random'}. Best is trial 2 with value: 0.7330559099441855.
# [I 2021-08-31 22:58:48,777] Trial 7 finished with value: 0.7399637633374914 and parameters: {'alpha': 4.712927228550414, 'l1_ratio': 0.35547163088445605, 'selection': 'random'}. Best is trial 2 with value: 0.7330559099441855.
# [I 2021-08-31 22:58:49,292] Trial 8 finished with value: 0.7399637633374914 and parameters: {'alpha': 3.4812696852737357, 'l1_ratio': 0.43598317760016597, 'selection': 'random'}. Best is trial 2 with value: 0.7330559099441855.
# [I 2021-08-31 22:58:49,817] Trial 9 finished with value: 0.7399637633374914 and parameters: {'alpha': 12.152076716819442, 'l1_ratio': 0.44969775900247655, 'selection': 'random'}. Best is trial 2 with value: 0.7330559099441855.
# [I 2021-08-31 22:58:50,354] Trial 10 finished with value: 0.7353791769801544 and parameters: {'alpha': 18.128256517940713, 'l1_ratio': 0.005405660709490612, 'selection': 'cyclic'}. Best is trial 2 with value: 0.7330559099441855.
# [I 2021-08-31 22:58:50,897] Trial 11 finished with value: 0.7349696812037113 and parameters: {'alpha': 18.383479467560548, 'l1_ratio': 0.004661234380830298, 'selection': 'cyclic'}. Best is trial 2 with value: 0.7330559099441855.
# [I 2021-08-31 22:58:51,424] Trial 12 finished with value: 0.7368316418854695 and parameters: {'alpha': 15.887147251572333, 'l1_ratio': 0.009052321508225197, 'selection': 'cyclic'}. Best is trial 2 with value: 0.7330559099441855.
# [I 2021-08-31 22:58:51,932] Trial 13 finished with value: 0.7399637633374914 and parameters: {'alpha': 7.973056488888652, 'l1_ratio': 0.0782240880173063, 'selection': 'cyclic'}. Best is trial 2 with value: 0.7330559099441855.
# [I 2021-08-31 22:58:52,441] Trial 14 finished with value: 0.7399637633374914 and parameters: {'alpha': 19.946714509352965, 'l1_ratio': 0.21813292691634872, 'selection': 'cyclic'}. Best is trial 2 with value: 0.7330559099441855.
# [I 2021-08-31 22:58:53,008] Trial 15 finished with value: 0.7399637633374914 and parameters: {'alpha': 15.957600112718339, 'l1_ratio': 0.04449700985395558, 'selection': 'cyclic'}. Best is trial 2 with value: 0.7330559099441855.
# [I 2021-08-31 22:58:53,531] Trial 16 finished with value: 0.7399637633374914 and parameters: {'alpha': 7.109180635093924, 'l1_ratio': 0.19484769399385066, 'selection': 'cyclic'}. Best is trial 2 with value: 0.7330559099441855.
# [I 2021-08-31 22:58:54,075] Trial 17 finished with value: 0.7399637633374914 and parameters: {'alpha': 11.789427831850496, 'l1_ratio': 0.10485504451340724, 'selection': 'cyclic'}. Best is trial 2 with value: 0.7330559099441855.
# [I 2021-08-31 22:58:54,734] Trial 18 finished with value: 0.7084256994134587 and parameters: {'alpha': 0.2615331130007075, 'l1_ratio': 0.001254316874039596, 'selection': 'cyclic'}. Best is trial 18 with value: 0.7084256994134587.
# [I 2021-08-31 22:58:55,456] Trial 19 finished with value: 0.7089210276610559 and parameters: {'alpha': 0.14831834746016703, 'l1_ratio': 0.15915139820347302, 'selection': 'cyclic'}. Best is trial 18 with value: 0.7084256994134587.
# [I 2021-08-31 22:58:56,117] Trial 20 finished with value: 0.7158447958505101 and parameters: {'alpha': 0.29937274172380984, 'l1_ratio': 0.3195805646941637, 'selection': 'cyclic'}. Best is trial 18 with value: 0.7084256994134587.
# [I 2021-08-31 22:58:56,784] Trial 21 finished with value: 0.7144446423950755 and parameters: {'alpha': 0.2810101055675128, 'l1_ratio': 0.3033852649909541, 'selection': 'cyclic'}. Best is trial 18 with value: 0.7084256994134587.
# [I 2021-08-31 22:58:57,308] Trial 22 finished with value: 0.7399637633374914 and parameters: {'alpha': 1.0608406678675655, 'l1_ratio': 0.3125005875326061, 'selection': 'cyclic'}. Best is trial 18 with value: 0.7084256994134587.
# [I 2021-08-31 22:58:58,303] Trial 23 finished with value: 0.7082342470813776 and parameters: {'alpha': 0.03208231990516211, 'l1_ratio': 0.1783720809424116, 'selection': 'cyclic'}. Best is trial 23 with value: 0.7082342470813776.
# [I 2021-08-31 22:58:58,814] Trial 24 finished with value: 0.7399637633374914 and parameters: {'alpha': 2.0311140137823926, 'l1_ratio': 0.16372328327998423, 'selection': 'cyclic'}. Best is trial 23 with value: 0.7082342470813776.
# [I 2021-08-31 22:58:59,332] Trial 25 finished with value: 0.7399637633374914 and parameters: {'alpha': 5.617769642432415, 'l1_ratio': 0.25265703338142215, 'selection': 'cyclic'}. Best is trial 23 with value: 0.7082342470813776.
# [I 2021-08-31 22:58:59,847] Trial 26 finished with value: 0.7399637633374914 and parameters: {'alpha': 1.9884467250471718, 'l1_ratio': 0.1674992723002311, 'selection': 'cyclic'}. Best is trial 23 with value: 0.7082342470813776.
# [I 2021-08-31 22:59:00,856] Trial 27 finished with value: 0.7081999491552178 and parameters: {'alpha': 0.027386668231327474, 'l1_ratio': 0.08256328395565314, 'selection': 'cyclic'}. Best is trial 27 with value: 0.7081999491552178.
# [I 2021-08-31 22:59:01,392] Trial 28 finished with value: 0.7376104696980509 and parameters: {'alpha': 3.463243311555157, 'l1_ratio': 0.05652765817388851, 'selection': 'cyclic'}. Best is trial 27 with value: 0.7081999491552178.
# [I 2021-08-31 22:59:01,902] Trial 29 finished with value: 0.7399637633374914 and parameters: {'alpha': 6.287445094618762, 'l1_ratio': 0.08909423900985361, 'selection': 'cyclic'}. Best is trial 27 with value: 0.7081999491552178.
# Number of finished trials: 30
# Best trial: {'alpha': 0.027386668231327474, 'l1_ratio': 0.08256328395565314, 'selection': 'cyclic'}

# %%
study.best_params
# Out:
# {'alpha': 0.01007142705729236,
#  'l1_ratio': 0.016602494998331628,
#  'selection': 'cyclic'}

# %% [markdown]
# # Log
#
# ========== 3 preds ==============
# ====== Ordinal encoding =========
#
# 0.708184718399365 {'alpha': 0.01007142705729236, 'l1_ratio': 0.016602494998331628, 'selection': 'cyclic'}
#
# ====== One-hot encoding =========
